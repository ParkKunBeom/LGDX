# %% [markdown]
# ### 학습목표
# - 사용자 정의함수를 파일로 정의하여 다른 파일에서 불러와 사용할 수 있다.

# %% [markdown]
# - Module.py 파일 내에 있는 함수 사용
# - 현재 실습파일과 동일한 위치에 존재하도록

# %%
# 로딩하는 방법
# 저장한 .py 파일의 이름과 동일해야한다
import Module

# %%
# 라이브러리명.함수
Module.add_num(1,2)
# Out:
# 3

# %%
# 라이브러리 이름에 별칭 붙이
import Module as md

# %%
md.sub_num(5,2)
# Out:
# 3

# %%
# 모듈(라이브러리) 내에 자주 사용하는 함수만 불러와서 사용
# 특정 모듈은 안에 많은 기능들과 데이터를 포함하여 무거운 경우에 활용
from Module import add_num #Moudle 안에 있는 add_num 기능만 가져옴

# %%
add_num(1,2)
# Out:
# 3

# %%
# 모듈내의특정 함수만 불러온 경우 빼기 기능은 사용 불가!
sub_num(5,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 모듈내의특정 함수만 불러온 경우 빼기 기능은 사용 불가!
# ----> 2 sub_num(5,3)
#
# NameError: name 'sub_num' is not defined
