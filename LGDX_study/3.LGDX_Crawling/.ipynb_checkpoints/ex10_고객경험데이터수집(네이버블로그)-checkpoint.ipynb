# %% [markdown]
# ### 학습목표
# - 네이버 블로그 데이터 수집하기
# - 네이버 카페 데이터를 수집했던 경험을 통하여 동일한 프로세스로 블로그 글 수집하기~
# - 수집 후 워드클라우드 생성

# %% [markdown]
# ##### 실습 순서
# 1. '음식물 처리기 사용 후기' 검색결과를 블로그 링크 분석
# 2. 키워드 검색, 기간설정이 가능한 url을 생성 (6개월)
# 3. 드라이버를 통하여 페이지 요청
# 4. 스크롤 내리기 10번
# 5. 블로그 주소 수집 (href_list)
# 6. 블로그 접근하여 본문 수집 (iframe)
# 7. 코드를 통합하여 모든 블로그 글 수집
# 8. 텍스트 데이터 txt 파일로 저장
# 9. 텍스트 전처리
# 10. 워드클라우드 생성

# %%
# 라이브러리 불러오기
import selenium.webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from tqdm import tqdm
import pandas as pd
import re # 정규표현식
from urllib.parse import quote
keyword = quote('음식물 처리기 사용 후기')

# 문자열 전처리 함수 -> 숫자, 문자, (?.!,¿) 제외하고 공백으로 대체
def preprocess_sentence_kr(w):
  w = w.strip()
  w = re.sub(r"[^0-9가-힣?.!,¿]+", " ", w) 
  w = w.strip() 
  return w

# %%
# date_option 패턴: 0(전체), 1(1시간),2(1일),3(1주),4(1개월),5(3개월),6(6개월), 7(1년)
date_option = input('date_option(all, 1d, 1h, 1m, 3m, 6m, 1y) >> ' )
url = f'https://search.naver.com/search.naver?ssc=tab.blog.all&query=%{keyword}&sm=tab_opt&nso=so%3Ar%2Cp%3A{date_option}'
url
# Out:
# date_option(all, 1d, 1h, 1m, 3m, 6m, 1y) >>  6m
# 'https://search.naver.com/search.naver?ssc=tab.blog.all&query=%%EC%9D%8C%EC%8B%9D%EB%AC%BC%20%EC%B2%98%EB%A6%AC%EA%B8%B0%20%EC%82%AC%EC%9A%A9%20%ED%9B%84%EA%B8%B0&sm=tab_opt&nso=so%3Ar%2Cp%3A6m'

# %%
driver = wb.Chrome()
driver.get(url)

# %%
#스크롤
for i in range(10):
    body = driver.find_element(By.TAG_NAME,'body')
    body.send_keys(Keys.END)
    time.sleep(1)

# %%
# 블로그 주소 수집
href_list=[]
link = driver.find_elements(By.CSS_SELECTOR,'a.fender-ui_228e3bd1.yEnIcjNmMJN3_9CrNfSS')
for i in range(len(link)):
    href_list.append(link[i].get_attribute('href'))

# %%
len(href_list)
# Out:
# 330

# %%
# 블로그 접근 본문 수집(iframe)
driver.get(href_list[0])
time.sleep(2)
driver.switch_to.frame('mainFrame')
driver.find_element(By.CLASS_NAME,'se-main-container').text
# Out:
# '오늘은 음식물처리기 일반쓰레기 사용 방법 및 처리 후기를 남겨 볼게요.\n저는 어려서부터 비위 약한 걸 못 봤어요!\n그런데 결혼하고 나니까, 이것 때문에 골병 썩게 됐는데요. 남편이 올 때까지 치우지 않으면 냄새가 올라오더라고요. 집에는 악취가 쌓이고요.\n그래서 최후의 수단으로, 음식물처리기를 사야겠다고 마음 먹었습니다. 흔쾌히 오케이 해주어서, 바로 좋은 제품을 찾아보기로 했죠.\n음식물처리기 일반쓰레기 제품은 에어메이드 더 브릭스 AFC-451이에요.\n직접 사용해보면서 느꼈던 점이 많았는데요. 막상 쓰기 시작하니까, 너무 편해서 사길 잘했다는 생각이 저절로 들 정도랍니다.\n그러면 바로 사용 방법과 처리 후기를 남겨볼게요!\n우선 제가 궁금했던 건 “분쇄가 된 음식물은 일반쓰레기에 버려도 될까?”였어요.\n음식물처리기 일반쓰레기 공용 사용은 불가능이었습니다.\n즉, 음식물쓰레기는 일반쓰레기로 버리면 안 된다는 이야기가 많아요. 건조, 분쇄가 되었다고 하더라고, 폐기물의 종류가 바뀌는 게 아니라는 의견 때문이라고 합니다!\n음식물처리기 일반쓰레기 차이는 음쓰에 유기물 성분이 그대로 남아있기 때문이었어요.\n그렇기 때문에, 향후 사료나 퇴비로 사용될 수 있다는 점을 고려해! 일반 쓰레기로 버리면 안 된다는 말에 힘을 실어주었죠.\n그래서 저희는 열풍이 되는 상품을 구매했지만, 여전히 음쓰 봉지에 버리고 있습니다. 좋은 점은 냄새가 안 난다는 점!\n그래서 서로 다르게 버려야 한다는 걸 인지하고, 제품을 알아 봤습니다!\n종류는 미생물, 발효, 건조, 열풍건조 등이 있었어요. 저는 열풍으로 건조해주고 분쇄해주는 방식이 더 마음에 들었는데요. 찾아 보니까 위 아래서 열을 가해주기 때문에, 더 확실하게 건조가 되면서 깨끗하게 분쇄가 된다더라고요.\n음식물처리기 사용 방법은 음식물을 모아, 한 데에 넣어 놓고 ‘시작’ 버튼만 누르면 되는 거였어요.\n추운 날 밖에 나가지 않고도, 빠르게 처리할 수 있음에 감사했는데요. 빠르게 처리하는 것도 좋은데, 냄새가 나지 않는 것도 완전 마음에 들었습니다.\n냄새는 2중 밥솥 패킹으로 밀폐력이 엄청났습니다. 게다가 계단식 필터 구조로, 냄새가 새어나오지 않게 막아주는 역할을 한다더라고요.\n그래서 그런지 몰라도, 저는 사용하면서 악취를 느꼈던 적이 단 한 번도 없었어요. 남편도 이정도면 그냥 봉지째 냅뒀을 때보다 훨씬 더 효율적이고 좋다며 행복해 했습니다.\n그리고 분쇄 칼날이 정말 좋아요. 4중 블레이드 칼날로 구성돼 있는데요. 크게 한 번 잘라주고, 잘게 또 한 번 잘라주는 기능이 딱 마음에 들었어요.\n나중에 꺼내 보면 정말 잘게 부서져 있어서 버리기도 간편하답니다. 한 번 돌리고 나면, 그렇게 많이 나오는 수준도 아니라서 이틀에 한 번씩 버리고 있어요.\n예전에는 부피가 커서, 바로 버리지 않으면 봉지가 터질 것 같았거든요. 그거 보고 있으면 짜증나기도 했죠.ㅠㅠ\n그런데 요즘은 그냥 두기만 해도, 미관상 헤치지 않아서 더 편하게 사용하고 있어요. 누차 말씀드리지만, 악취? 그런 건 완전히 생각하지 않아도 돼서 더 행복해요.ㅠㅠ\n위, 아래 두 개의 열로 건조를 확실하게 해주니, 떡지는 것도 없고 눌러 붙는 것도 없어서 너무 편안해요.\n사이즈는 각티슈 사이즈에요. 세로로는 조금 더 높긴 한데요. 부엌에 두면, 자리가 비좁거나 하지 않더라고요. 저는 밥솥 옆에 두기는 좀 그래서, 정수기 옆에 두고 사용하고 있는데요. 걸리적거리지 않고 편하게 사용할 수 있는 게 참 매력적이에요!\n그리고 열풍 기술 때문에, 기기 안에 물맺힘이 있는 건 아닐까? 걱정했던 때도 있었는데요. 그런데 열 처리 후 습기가 알아서 제거가 되니, 빠르게 건조시킬 수 있었어요. 물 때, 곰팡이, 물 맺힘으로 인한 냄새 걱정이 전혀 안 들었습니다.\n이제는 너무 편하게 쓰고 있어서, 없어서는 안 되는 것 중 하나에요! 전기 요금도 1회 사용시 84원 정도라서, 2배 이상 절약할 수 있다는 게 최고! 요즘은 사용할 때마다 걱정 없이 쓴다는 게 가장 마음이 놓이는 부분 중 하나에요.\n마지막으로 한 가지 사용하면서 느낀, 한 가지 장점을 더 말씀드릴게요! 더 브릭스는 직관적인 사용 방법이라 쓰기가 좋습니다.\n어르신들도 어렵지 않게 쓸 것 같아서, 친정과 시댁에 선물로 드리려고 해요. 어떤 음식을 넣어도, 스스로 감지하고 알맞은 시간에 맞춰서 처리해주니까 건들일 게 없습니다!\nAI로 처리해주는 똑똑하고 스마트한 음처기가 필요하다면 딱 괜찮은 것 같아요. 저는 그래서, 요즘은 더 잘 쓰고 있고! 남편도 제가 없을 때 유용하게 쓰고 있다며 가장 잘산템이라고 말한답니다.\n이렇게 해서 음식물처리기 일반쓰레기 사용 방법 및 처리 후기를 적어 봤는데요.\n음식물 처리 방법은 일반적으로 하는 방식을 그대로 따라하면 돼서 어렵진 않습니다. 대신에, 사용하면서 냄새도 안 나고! 부피도 줄어드니! 처리하는 게 오히려 더 쉬워졌어요!\n그래서 저는 신혼부부, 어르신들에게 강추합니다!\n에어메이드 듀얼 히팅 4.5L 대용량 음식물 처리기 더 브릭스 AFC-451 가정용 분쇄기 : 에어메이드\n[에어메이드] 기분 좋은 바람을 만드는 곳\nm.site.naver.com\n음식물처리기 일반쓰레기 사용 방법 및 처리 후기\n재생\n14\n좋아요\n0\n00:12\n\n음식물처리기 일반쓰레기 사용 방법 및 처리 후기'

# %%
f = open('./data/음식물 쓰레기 블로그 데이터.txt','w')

# 링크 반복
for i in tqdm(range(len(href_list))):
    driver.get(href_list[i])
    time.sleep(2)
    driver.switch_to.frame('mainFrame')

    result = driver.find_element(By.CLASS_NAME,'se-main-container')
    content = preprocess_sentence_kr(result.text)
    f.write(content)

f.close()
# Out:
# 100%|██████████| 330/330 [15:27<00:00,  2.81s/it]

# %%
# 텍스트 파일 열기
f = open('./data/음식물 쓰레기 블로그 데이터.txt','r')
text = f.readline()
f.close()

# %%
from kiwipiepy import Kiwi # 키위 형태소 분석기
from wordcloud import WordCloud # 워드클라우드 생성 도구
from collections import Counter # 단어가 나온 횟수를 세주는 도구
import matplotlib.pyplot as plt #t시각화도구
# mask 이미지를 만들기 위한 도구
from PIL import Image
import numpy as np

# %%
# 도구 객체생성
kiwi = Kiwi()
# 토큰화
token = kiwi.tokenize(text)

nn_list=[]
for t in token:
    if t.tag in ['NNG','NNP']:
        nn_list.append(t.form)

# %%
top_100 = Counter(nn_list).most_common(100)
top_100
# Out:
# [('음식물', 7779),
#  ('처리', 6998),
#  ('사용', 3167),
#  ('냄새', 2154),
#  ('분쇄', 1609),
#  ('쓰레기', 1598),
#  ('제품', 1504),
#  ('건조', 1418),
#  ('주방', 1411),
#  ('후기', 1132),
#  ('때', 1120),
#  ('후', 853),
#  ('관리', 831),
#  ('미닉스', 822),
#  ('가능', 814),
#  ('미생물', 803),
#  ('걱정', 790),
#  ('필터', 783),
#  ('정도', 769),
#  ('집', 766),
#  ('시간', 765),
#  ('생각', 757),
#  ('용량', 725),
#  ('작동', 717),
#  ('소음', 705),
#  ('추천', 692),
#  ('방식', 682),
#  ('가정', 674),
#  ('점', 670),
#  ('자동', 613),
#  ('세척', 610),
#  ('기능', 593),
#  ('분쇄기', 583),
#  ('필요', 580),
#  ('비교', 572),
#  ('고민', 548),
#  ('설치', 530),
#  ('선택', 529),
#  ('모드', 524),
#  ('부담', 516),
#  ('디자인', 487),
#  ('구매', 485),
#  ('통', 461),
#  ('일', 439),
#  ('부분', 424),
#  ('가전', 415),
#  ('버튼', 404),
#  ('구조', 402),
#  ('스트레스', 395),
#  ('싱크대', 393),
#  ('아이', 386),
#  ('덕분', 385),
#  ('물', 384),
#  ('내부', 373),
#  ('처음', 364),
#  ('브랜드', 361),
#  ('마음', 356),
#  ('생활', 355),
#  ('만족', 350),
#  ('공간', 350),
#  ('뼈', 347),
#  ('스마트', 346),
#  ('하루', 334),
#  ('교체', 333),
#  ('확인', 331),
#  ('문제', 327),
#  ('린', 322),
#  ('더', 317),
#  ('뚜껑', 317),
#  ('편리', 312),
#  ('손', 312),
#  ('악취', 308),
#  ('에어', 305),
#  ('위생', 298),
#  ('메이드', 297),
#  ('장점', 297),
#  ('봉투', 297),
#  ('끝', 296),
#  ('성능', 296),
#  ('일반', 294),
#  ('시작', 289),
#  ('기준', 287),
#  ('가루', 285),
#  ('껍질', 285),
#  ('과정', 284),
#  ('인', 283),
#  ('전', 282),
#  ('쿠쿠', 279),
#  ('사이즈', 275),
#  ('신경', 274),
#  ('양', 274),
#  ('느낌', 270),
#  ('이유', 270),
#  ('정리', 268),
#  ('보관', 267),
#  ('중요', 262),
#  ('가족', 261),
#  ('음식', 259),
#  ('블루', 256),
#  ('벤트', 255)]

# %%
# 이미지 열어서 마스크이미지로 변환
# 이미지의 흰색 부분은 단어를 채우지 않고, 그 이외에 색이 있는 부분에 단어를 채우는 원리
img = Image.open('./data/jg.jpg')
mask_img = np.array(img)

wc = WordCloud(
    font_path='C:/Windows/Fonts/malgunbd.ttf',
    background_color='white', mask=mask_img, colormap='spring'
).generate_from_frequencies(dict(top_100))
plt.imshow(wc)
plt.axis('off')
plt.show()
