# %% [markdown]
# ### 학습목표
# - 영화 리뷰데이터 수집(블로그)할 수 있다.
# - 수집한 데이터를 시각화 하기 위한 전처리를 할 수 있다.
# - 워드클라우드를 생성할 수 있다

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import re # 정규표현식 활용

# %%
# 영화 리뷰데이터가 들어있는 블로그 주소
url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&ssc=tab.nx.all&query=%EC%95%84%EB%B0%94%ED%83%803+%EB%A6%AC%EB%B7%B0&oquery=%EC%95%84%EB%B0%94%ED%83%802+%EB%A6%AC%EB%B7%B0&tqi=jUsNTwqos5ossi2ZKPZ-342894&ackey=74e97f8t'
res = req.get(url)
soup = bs(res.text, 'lxml')

# %% [markdown]
# ### 프로세스
# 1. 영화리부가 작성된 블로그 제목 및 주소 수집
# 2. 리뷰가 작성된 블로그의 리뷰내용 수집(첫번째 블로그에서 수집)
# 3. 여러개의 블로그 리뷰내용 수집
# 4. 수집한 텍스트데이터 전처리
# 5. 워드클라우드 생성하기~

# %% [markdown]
# 1. 영화리부가 작성된 블로그 제목 및 주소 수집

# %%
#블로그 주소 저장
href_list=[]
a_tag = soup.select('.list_title>a.review_link') # soup.select('.review_info._ellipsis>a.review_link')
for i in range(len(a_tag)):
    href_list.append(a_tag[i].get('href'))
href_list
# Out:
# ['https://blog.naver.com/syunni1225/224115606045',
#  'https://blog.naver.com/kaminari2002/224114898643',
#  'https://blog.naver.com/seok9c/224115025215',
#  'https://blog.naver.com/duswns202/224106859517',
#  'https://blog.naver.com/dudghkrkwhgdms/224115758710',
#  'https://blog.naver.com/blac_beat/224128473123',
#  'https://blog.naver.com/realnogun/224113577463',
#  'https://blog.naver.com/c106507/224111497322',
#  'https://blog.naver.com/sta-tio/224114494844',
#  'https://blog.naver.com/stmisn/224091045516']

# %%
#블로그 제목 추출
soup.select('span.this_text')
# Out:
# [<span class="this_text">아바타: 불과 재(Avatar: Fire and Ash, 2025) 영화 정보... </span>,
#  <span class="this_text">&lt;아바타3: 불과 재&gt; 4Dx3D후기 :: 그래도 극장에서 봐야하는 영화.... </span>,
#  <span class="this_text">사실상 아바타 2.5가 아니었나, 영화 &lt;아바타: 불과 재&gt; 후기</span>,
#  <span class="this_text">영화 아바타 불과 재 12세 관람가 러닝타임 등급 심사표 공개 수위</span>,
#  <span class="this_text">아바타 3 불과 재 쿠키 영상 정보 영화 리뷰</span>,
#  <span class="this_text">영화 아바타3: 불과 재(2025) 정보, 줄거리, 결말, 후기</span>,
#  <span class="this_text">영화 아바타 3편 불과 재 줄거리 결말 쿠키없음</span>,
#  <span class="this_text">아바타 불과재 출격! 12월 셋째주 개봉 예정 영화</span>,
#  <span class="this_text">[영화 리뷰] 아바타: 불과 재 (2025년) 감상평과 후기, 영화 정보... </span>,
#  <span class="this_text">영화 '아바타: 불과 재' 시사회 초청 이벤트, KT 멤버십 X 롯데시네마</span>]

# %% [markdown]
# - 첫번째 블로그 내용 수집하기!

# %%
# 첫번째 페이지의 정보 받아오기
res1 = req.get(href_list[0])
soup1 = bs(res1.text, 'lxml')

# %%
soup1.select('div.se-main-container')
soup1.select('#post-view224115606045 > div > div.se-main-container')
# Out:
# []

# %% [markdown]
# ### iframe
# - 하나의 페이지에 많은 양의 데이터가 저장되어있으면 페이지가 무거워짐 -> 속도가 느려짐
# - 데이터는 다른 저장사이트에 저장해두고 현재 페이지에서는 보여주기만하는 형태로 출력
# - 데이터 수집을 위해서 실제 데이터가 저장된 공간으로 접근
# - ex) 블로그, 카페, 지식인, 지도

# %% [markdown]
# - 실제 데이터의 주소
#   - 메인 주소값 + src -> 실제 블로그 주소 생성
#   - https://blog.naver.com/ + src

# %%
# src 추출하기sr
src = soup1.select_one('iframe#mainFrame').get('src')
# 실제 주소 완성하기
# 메인주소 + src
blog_url = 'https://blog.naver.com' + src
blog_url
# Out:
# 'https://blog.naver.com/PostView.naver?blogId=syunni1225&logNo=224115606045&redirect=Dlog&widgetTypeCall=true&noTrackingCode=true&directAccess=false'

# %% [markdown]
# - 1개 블로그의 리뷰 수집

# %%
# blog_url 의 페이지 정보 요청, 응답
res2 = req.get(blog_url)
soup2 = bs(res2.text,'lxml')

# %%
# blog_url 페이지에서 리뷰내용 수집
soup2.select('.se-fs-fs26.se-ff-')[0].text
# Out:
# '아바타: 불과 재(Avatar: Fire and Ash, 2025) 영화 정보, 리뷰ː데우스 엑스 마키나적 해결법'

# %%
content = soup2.select('.se-main-container')[0].text
content
# Out:
# "\n\n\n\n\n영화 <아바타: 불과 재> 정보, 줄거리, 리뷰\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\u200b\u200b\u200b\n\n\n\n\n \n\n\n\n영화 정보\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n기본 정보\n\n\n\n\n\n\n\n\n원제 : Avatar: Fire and Ash수입/배급 : 월트디즈니 컴퍼니 코리아감독 : 제임스 카메론출연 : 샘 워싱턴, 조이 살다나, 시고니 위버, 스티븐 랭, 우나 채플린, 케이트 윈슬렛 외제작 국가 : 미국장르 : 액션, 어드벤처(모험), 판타지, SF, 스릴러관람 등급 : 12세 이상 관람가상영 시간 : 195분극장 개봉 : 2025년 12월 17일\u200b\n\n\n\n\n \n\n\n\n줄거리\n\n\n\n\n\n\n\n\n큰아들을 잃은 제이크 설리와 네이티리 가족은 저마다 애도를 하고 있다. 그러던 중 그들 가족에게 다시 위기가 찾아오는데...\u200b\u200b\u200b\n\n\n\n\n \n\n\n\n리뷰로 보는 관람 포인트\n\n\n\n\n\n\n\n\n여전히 말 안 듣는 아이들\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n3편을 보기 위해 굳이 2편을 복습하지 않아도 될 것 같아 일단 보기 시작한 영화 오프닝에서는 전편에서 사망한 네테이얌이 등장해 로아크와 자유롭게 비행을 하는 모습을 보여줬다. 나비족만이 할 수 있는 의식 같은 걸로 로아크는 죽은 형과 대화하며 즐거운 시간을 보낼 수 있던 것이었다.로아크가 자신만의 방식으로 형을 그리워하고 있을 때 엄마인 네이티리는 상실감에 아무것도 하지 못하고 슬퍼하기만 했다. 그리고 설리는 인간이 다시금 공격을 해올 걸 예상해 바다에 가라앉은 인간들의 전함에서 총을 비롯한 각종 무기를 모으기 시작했다. 설리네 가족이 의지하고 있는 멧카이나의 부족장은 강하게 반발했지만 설리는 뜻을 굽히지 않았다.\u200b\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n그러던 중에 제이크는 인간인 스파이더를 바람 상인의 편에 보내려고 했다. 스파이더가 쿼리치의 아들이었기에 데리고 있으면 그가 언제든 다시 공격해올 수 있었기 때문이었다. 스파이더는 강하게 반발했고, 설리의 아이들까지도 가족이라며 보내면 안 된다고 했지만 부모의 뜻을 꺾을 수는 없었다. 그나마 함께 가서 데려다주고 오자는 의견으로 분위기가 조금 누그러졌다.\u200b바람 상인과 함께 떠나게 된 설리의 가족은 시작부터 불안불안하기만 했다. 이 사건 이전에 스파이더가 자던 중에 마스크에 문제가 생겨 죽을 뻔했었고, 설리가 로아크에게 무전기를 차야 한다고 했던 적이 있었다. 하지만 이 두 아이들은 당연히 말을 안 들었다. 전편에서 말 안 듣는 아이들 때문에 짜증 났던 기억이 남아 있는데, 이번에도 그러니 어처구니가 없었다. 네테이얌이 죽고서도 정신을 못 차렸다 싶었기 때문이다.이후 영화 후반으로 가면서 키리 역시 형제들이 말리는 데도 자신의 뜻대로 행동했고 막내 투크도 그랬다. 그리고 멧카이나 부족장의 딸 츠레이야 역시 후반에 자기 엄마에게 강하게 반발하는 등의 모습을 보였다. 그렇게 행동해야만 하는 이유가 있었지만, 말 안 듣는 애들을 워낙 끔찍해하는 나로서는 머리가 아플 지경이었다.\u200b\n\n\n\n\n \n\n\n\n우당탕탕 설리네 가족\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n설리 가족이 바람 상인과 함께 가던 중에 망콴족이 나타나 공격을 시작했고, 쿼리치는 제이크를 또 잡겠다며 나타났다. 그로 인해 한바탕 전쟁이 벌어져 자랑이라도 하려는 듯 뛰어난 CG 효과를 보여줬다. 일반 상영관에서 봤음에도 CG가 좋다는 건 알 수 있었다. 하지만 한 가지 의아했던 건 CG가 버벅거린다는 느낌이 드는 장면이 종종 있었다는 것이다.\u200b\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n망콴족 때문에 말 안 듣는 아이들은 자기들끼리 도망을 쳐야 했고 네이티리는 망콴족의 부족장 바랑이 쏜 활에 크게 다치고 말았다. 그리고 제이크는 쿼리치에게 붙잡히고 말았다. 제이크는 아이들이 무전기도 차지 않았고 스파이더의 마스크도 버려져 있는 걸 보고는 쿼리치에게 아이들을 먼저 구해야 한다고 말했다. 쿼리치는 제 아들에게 의외로 약했던 터라 얼마 동안 손을 잡고 아이들의 행적을 쫓기 시작했다.하지만 목표를 달성한 후에 제이크와 쿼리치는 다시 적으로 돌아갈 수밖에 없었다. 그로 인해 적의 적인 망콴의 바랑과 쿼리치가 손을 잡게 된 건 당연했다.\u200b\n\n\n\n\n \n\n\n\n<범죄도시> 시리즈를 보는 듯한 감흥\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n사실 나는 2편도 재미있게 보질 않았다. 3D 아이맥스로 봤고 기술력에 감탄하긴 했지만 그게 끝이었다. 영화를 영상미나 CG로만 보는 게 아닌 사람이라 별 내용이 없음에도 굳이 러닝타임이 3시간이 넘어야 하는지 의문스러웠다. 영화 전개를 위해 어쩔 수 없다 해도 말 안 듣는 아이들로 인해 사건 사고의 연속이라는 점 또한 마음에 들지 않았다.그래서 3편은 굳이 특별관에서 안 봐도 될 거라 생각해 일반 상영관에서 봤고, CG가 버벅거릴 때가 있긴 했으나 일반 상영관 스크린으로도 기술력이 뛰어나다는 건 인정이었다. 하지만 역시나 이 이야기를 또 3시간이 넘게 해야 하는지는 회의적이었다. 가족이 죽었는데도 아이들은 여전히 말을 안 들었고, 쿼리치는 전생의 원수라도 되는지 제이크를 포기하질 않았다. 또한 자연과 공생하는 나비족은 선하고 생명체와 자연을 파괴하는 인간은 나쁘다는 의미 또한 전편과 같았다. 물론 도움을 주는 착한 인간이 있었고, 제이크의 가족을 공격하는 망콴족 같은 악당으로 변화를 주긴 했지만 전체적으로 비슷하다는 인상을 지울 수 없었다.그로 인해 영화를 보는 내내 3편을 보는 건지, 2편을 보는 건지 큰 차이가 없다 여겨졌다. 잘라내도 되는 장면이 꽤 있어서 그것만 덜어냈다면 그래도 지금보다는 나았을 텐데, 아쉽게도 좋아하는 영화를 보는 일에 피로감을 느끼고 말았다.\u200b영화를 보며 떠올린 건 <범죄도시> 시리즈와 <아바타> 시리즈가 무슨 차이가 있냐는 것이다. 주먹으로 승부하는 형사 마석도가 범죄자를 소탕하는 <범죄도시>, 시각적인 즐거움으로 현실에 존재하지 않는 세계에 대해 말하는 <아바타>는 내게 큰 차이가 없었다. 시리즈가 전체적으로 패턴화된 것 역시 똑같았기에 전혀 흥미롭지 않았다.그리고 이번 영화에서 가장 아쉬웠던 건 여러 사건을 '데우스 엑스 마키나(Deus Ex Machina)'적으로 해결한 것이었다. 그 중심에 선 키리가 스파이더의 일을 비롯해 마지막 전투까지 다 해결하는 걸 보며 <아바타> 세계관의 신은 에이와가 아니라 키리인지도 모른다는 생각을 했다.\u200b\u200b\u200b\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n대부분의 사람들이 12월 최고 기대작으로 뽑았지만 나는 전혀 기대하지 않았던 <아바타: 불과 재>는 역시나 기대하지 않은 만큼의 인상을 남겼다. 여전한 캐릭터들과 사건 사고의 연속, 그러고선 결말엔 선한 자가 이기는 흐름을 뛰어난 CG로 덮어버리고 있었다. 영화는 시각적 효과보다 내용이 중요하다 여기는 내게는 아쉽기만 한 영화였지만, 오락 영화를 좋아하는 사람이라면 즐겁게 볼 것 같다.4편이 나올지 안 나올지 모르겠지만, 나온다면 이제 극장에서는 안 보지 않을까 싶다.\u200b\u200b\u200b덧. 영화 상영 전에 나온 <어벤져스: 둠스데이> 예고편 볼 때 제일 심장이 뛰었음.\u200b\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n아바타: 불과 재\n\n\nSF, 액션, 모험2025제임스 카메론 \n \n\n\n\n\n\n\n  "

# %% [markdown]
# - 정규표현식을 활용한 데이터 전처리~
#   - re
#   - 정규표현식: 문자열 내에서 특정규칙을 찾아 변경하는 도구

# %% [markdown]
# | 구성요소                  | 의미                       |
# | --------------------- | ------------------------ |
# | `r"..."`              | Raw string — 이스케이프 문자 무시 |
# | `[^ ... ]`            | 괄호 안 문자 **제외한** 문자들      |
# | `0-9`                 | 숫자                       |
# | `가-힣`                 | 모든 한글                    |
# | `?.!,¿`               | 허용할 문장 부호                |
# | `+`                   | 하나 이상 연속된 구간             |
# | `re.sub(..., " ", w)` | 매칭된 부분을 공백으로 치환          |

# %%
# 문자열 전처리 함수 -> 숫자, 문자, (?,!,¿) 제외하고 공백으로 대체
def preprocess_sentence_kr(w):
  w = w.strip()
  w = re.sub(r"[^0-9가-힣?.!,¿]+", " ", w) 
  w = w.strip() 
  return w

# %%
#함수 적용
preprocess_sentence_kr(content)
# Out:
# '영화 아바타 불과 재 정보, 줄거리, 리뷰 영화 정보 기본 정보 원제 수입 배급 월트디즈니 컴퍼니 코리아감독 제임스 카메론출연 샘 워싱턴, 조이 살다나, 시고니 위버, 스티븐 랭, 우나 채플린, 케이트 윈슬렛 외제작 국가 미국장르 액션, 어드벤처 모험 , 판타지, , 스릴러관람 등급 12세 이상 관람가상영 시간 195분극장 개봉 2025년 12월 17일 줄거리 큰아들을 잃은 제이크 설리와 네이티리 가족은 저마다 애도를 하고 있다. 그러던 중 그들 가족에게 다시 위기가 찾아오는데... 리뷰로 보는 관람 포인트 여전히 말 안 듣는 아이들 3편을 보기 위해 굳이 2편을 복습하지 않아도 될 것 같아 일단 보기 시작한 영화 오프닝에서는 전편에서 사망한 네테이얌이 등장해 로아크와 자유롭게 비행을 하는 모습을 보여줬다. 나비족만이 할 수 있는 의식 같은 걸로 로아크는 죽은 형과 대화하며 즐거운 시간을 보낼 수 있던 것이었다.로아크가 자신만의 방식으로 형을 그리워하고 있을 때 엄마인 네이티리는 상실감에 아무것도 하지 못하고 슬퍼하기만 했다. 그리고 설리는 인간이 다시금 공격을 해올 걸 예상해 바다에 가라앉은 인간들의 전함에서 총을 비롯한 각종 무기를 모으기 시작했다. 설리네 가족이 의지하고 있는 멧카이나의 부족장은 강하게 반발했지만 설리는 뜻을 굽히지 않았다. 그러던 중에 제이크는 인간인 스파이더를 바람 상인의 편에 보내려고 했다. 스파이더가 쿼리치의 아들이었기에 데리고 있으면 그가 언제든 다시 공격해올 수 있었기 때문이었다. 스파이더는 강하게 반발했고, 설리의 아이들까지도 가족이라며 보내면 안 된다고 했지만 부모의 뜻을 꺾을 수는 없었다. 그나마 함께 가서 데려다주고 오자는 의견으로 분위기가 조금 누그러졌다. 바람 상인과 함께 떠나게 된 설리의 가족은 시작부터 불안불안하기만 했다. 이 사건 이전에 스파이더가 자던 중에 마스크에 문제가 생겨 죽을 뻔했었고, 설리가 로아크에게 무전기를 차야 한다고 했던 적이 있었다. 하지만 이 두 아이들은 당연히 말을 안 들었다. 전편에서 말 안 듣는 아이들 때문에 짜증 났던 기억이 남아 있는데, 이번에도 그러니 어처구니가 없었다. 네테이얌이 죽고서도 정신을 못 차렸다 싶었기 때문이다.이후 영화 후반으로 가면서 키리 역시 형제들이 말리는 데도 자신의 뜻대로 행동했고 막내 투크도 그랬다. 그리고 멧카이나 부족장의 딸 츠레이야 역시 후반에 자기 엄마에게 강하게 반발하는 등의 모습을 보였다. 그렇게 행동해야만 하는 이유가 있었지만, 말 안 듣는 애들을 워낙 끔찍해하는 나로서는 머리가 아플 지경이었다. 우당탕탕 설리네 가족 설리 가족이 바람 상인과 함께 가던 중에 망콴족이 나타나 공격을 시작했고, 쿼리치는 제이크를 또 잡겠다며 나타났다. 그로 인해 한바탕 전쟁이 벌어져 자랑이라도 하려는 듯 뛰어난 효과를 보여줬다. 일반 상영관에서 봤음에도 가 좋다는 건 알 수 있었다. 하지만 한 가지 의아했던 건 가 버벅거린다는 느낌이 드는 장면이 종종 있었다는 것이다. 망콴족 때문에 말 안 듣는 아이들은 자기들끼리 도망을 쳐야 했고 네이티리는 망콴족의 부족장 바랑이 쏜 활에 크게 다치고 말았다. 그리고 제이크는 쿼리치에게 붙잡히고 말았다. 제이크는 아이들이 무전기도 차지 않았고 스파이더의 마스크도 버려져 있는 걸 보고는 쿼리치에게 아이들을 먼저 구해야 한다고 말했다. 쿼리치는 제 아들에게 의외로 약했던 터라 얼마 동안 손을 잡고 아이들의 행적을 쫓기 시작했다.하지만 목표를 달성한 후에 제이크와 쿼리치는 다시 적으로 돌아갈 수밖에 없었다. 그로 인해 적의 적인 망콴의 바랑과 쿼리치가 손을 잡게 된 건 당연했다. 범죄도시 시리즈를 보는 듯한 감흥 사실 나는 2편도 재미있게 보질 않았다. 3 아이맥스로 봤고 기술력에 감탄하긴 했지만 그게 끝이었다. 영화를 영상미나 로만 보는 게 아닌 사람이라 별 내용이 없음에도 굳이 러닝타임이 3시간이 넘어야 하는지 의문스러웠다. 영화 전개를 위해 어쩔 수 없다 해도 말 안 듣는 아이들로 인해 사건 사고의 연속이라는 점 또한 마음에 들지 않았다.그래서 3편은 굳이 특별관에서 안 봐도 될 거라 생각해 일반 상영관에서 봤고, 가 버벅거릴 때가 있긴 했으나 일반 상영관 스크린으로도 기술력이 뛰어나다는 건 인정이었다. 하지만 역시나 이 이야기를 또 3시간이 넘게 해야 하는지는 회의적이었다. 가족이 죽었는데도 아이들은 여전히 말을 안 들었고, 쿼리치는 전생의 원수라도 되는지 제이크를 포기하질 않았다. 또한 자연과 공생하는 나비족은 선하고 생명체와 자연을 파괴하는 인간은 나쁘다는 의미 또한 전편과 같았다. 물론 도움을 주는 착한 인간이 있었고, 제이크의 가족을 공격하는 망콴족 같은 악당으로 변화를 주긴 했지만 전체적으로 비슷하다는 인상을 지울 수 없었다.그로 인해 영화를 보는 내내 3편을 보는 건지, 2편을 보는 건지 큰 차이가 없다 여겨졌다. 잘라내도 되는 장면이 꽤 있어서 그것만 덜어냈다면 그래도 지금보다는 나았을 텐데, 아쉽게도 좋아하는 영화를 보는 일에 피로감을 느끼고 말았다. 영화를 보며 떠올린 건 범죄도시 시리즈와 아바타 시리즈가 무슨 차이가 있냐는 것이다. 주먹으로 승부하는 형사 마석도가 범죄자를 소탕하는 범죄도시 , 시각적인 즐거움으로 현실에 존재하지 않는 세계에 대해 말하는 아바타 는 내게 큰 차이가 없었다. 시리즈가 전체적으로 패턴화된 것 역시 똑같았기에 전혀 흥미롭지 않았다.그리고 이번 영화에서 가장 아쉬웠던 건 여러 사건을 데우스 엑스 마키나 적으로 해결한 것이었다. 그 중심에 선 키리가 스파이더의 일을 비롯해 마지막 전투까지 다 해결하는 걸 보며 아바타 세계관의 신은 에이와가 아니라 키리인지도 모른다는 생각을 했다. 대부분의 사람들이 12월 최고 기대작으로 뽑았지만 나는 전혀 기대하지 않았던 아바타 불과 재 는 역시나 기대하지 않은 만큼의 인상을 남겼다. 여전한 캐릭터들과 사건 사고의 연속, 그러고선 결말엔 선한 자가 이기는 흐름을 뛰어난 로 덮어버리고 있었다. 영화는 시각적 효과보다 내용이 중요하다 여기는 내게는 아쉽기만 한 영화였지만, 오락 영화를 좋아하는 사람이라면 즐겁게 볼 것 같다.4편이 나올지 안 나올지 모르겠지만, 나온다면 이제 극장에서는 안 보지 않을까 싶다. 덧. 영화 상영 전에 나온 어벤져스 둠스데이 예고편 볼 때 제일 심장이 뛰었음. 아바타 불과 재 , 액션, 모험2025제임스 카메론'

# %% [markdown]
# - 수집한 10개 블로그리뷰를 텍스트 파일로 저장하기~

# %%
len(href_list)
# Out:
# 10

# %%
from tqdm import tqdm

# %%
# open 함수를 사용하여 파일 열어서 초기화
f = open('./data/movie_review.txt', 'w', encoding = 'utf-8')
# 반복문을 활용하여 블로그 주소 10개를 반복
for i in tqdm(range(len(href_list))):
    res1 = req.get(href_list[i])
    soup1 = bs(res1.text, 'lxml')

    # ifrmae src 속성값을 추출하여 실제 블로그 주소 생성
    src = soup1.select_one('iframe#mainFrame').get('src')
    blog_url = 'https://blog.naver.com' + src

    # 실제 내용이 들어있는 블로그 페이지 정보 받아오기
    res2 = req.get(blog_url)
    soup2 = bs(res2.text,'lxml')

    # 본문내용 수집, 전처리
    content = soup2.select('.se-main-container')[0].text
    final_content = preprocess_sentence_kr(content)
    f.write(final_content)
f.close() # 파일 닫기
# Out:
# 100%|██████████| 10/10 [00:21<00:00,  2.13s/it]

# %% [markdown]
# - 워드클라우드 생성

# %%
f = open('./data/movie_review.txt', 'r' , encoding='utf-8')
review = f.readline()
f.close()

# %%
review
# Out:
# '영화 아바타 불과 재 정보, 줄거리, 리뷰 영화 정보 기본 정보 원제 수입 배급 월트디즈니 컴퍼니 코리아감독 제임스 카메론출연 샘 워싱턴, 조이 살다나, 시고니 위버, 스티븐 랭, 우나 채플린, 케이트 윈슬렛 외제작 국가 미국장르 액션, 어드벤처 모험 , 판타지, , 스릴러관람 등급 12세 이상 관람가상영 시간 195분극장 개봉 2025년 12월 17일 줄거리 큰아들을 잃은 제이크 설리와 네이티리 가족은 저마다 애도를 하고 있다. 그러던 중 그들 가족에게 다시 위기가 찾아오는데... 리뷰로 보는 관람 포인트 여전히 말 안 듣는 아이들 3편을 보기 위해 굳이 2편을 복습하지 않아도 될 것 같아 일단 보기 시작한 영화 오프닝에서는 전편에서 사망한 네테이얌이 등장해 로아크와 자유롭게 비행을 하는 모습을 보여줬다. 나비족만이 할 수 있는 의식 같은 걸로 로아크는 죽은 형과 대화하며 즐거운 시간을 보낼 수 있던 것이었다.로아크가 자신만의 방식으로 형을 그리워하고 있을 때 엄마인 네이티리는 상실감에 아무것도 하지 못하고 슬퍼하기만 했다. 그리고 설리는 인간이 다시금 공격을 해올 걸 예상해 바다에 가라앉은 인간들의 전함에서 총을 비롯한 각종 무기를 모으기 시작했다. 설리네 가족이 의지하고 있는 멧카이나의 부족장은 강하게 반발했지만 설리는 뜻을 굽히지 않았다. 그러던 중에 제이크는 인간인 스파이더를 바람 상인의 편에 보내려고 했다. 스파이더가 쿼리치의 아들이었기에 데리고 있으면 그가 언제든 다시 공격해올 수 있었기 때문이었다. 스파이더는 강하게 반발했고, 설리의 아이들까지도 가족이라며 보내면 안 된다고 했지만 부모의 뜻을 꺾을 수는 없었다. 그나마 함께 가서 데려다주고 오자는 의견으로 분위기가 조금 누그러졌다. 바람 상인과 함께 떠나게 된 설리의 가족은 시작부터 불안불안하기만 했다. 이 사건 이전에 스파이더가 자던 중에 마스크에 문제가 생겨 죽을 뻔했었고, 설리가 로아크에게 무전기를 차야 한다고 했던 적이 있었다. 하지만 이 두 아이들은 당연히 말을 안 들었다. 전편에서 말 안 듣는 아이들 때문에 짜증 났던 기억이 남아 있는데, 이번에도 그러니 어처구니가 없었다. 네테이얌이 죽고서도 정신을 못 차렸다 싶었기 때문이다.이후 영화 후반으로 가면서 키리 역시 형제들이 말리는 데도 자신의 뜻대로 행동했고 막내 투크도 그랬다. 그리고 멧카이나 부족장의 딸 츠레이야 역시 후반에 자기 엄마에게 강하게 반발하는 등의 모습을 보였다. 그렇게 행동해야만 하는 이유가 있었지만, 말 안 듣는 애들을 워낙 끔찍해하는 나로서는 머리가 아플 지경이었다. 우당탕탕 설리네 가족 설리 가족이 바람 상인과 함께 가던 중에 망콴족이 나타나 공격을 시작했고, 쿼리치는 제이크를 또 잡겠다며 나타났다. 그로 인해 한바탕 전쟁이 벌어져 자랑이라도 하려는 듯 뛰어난 효과를 보여줬다. 일반 상영관에서 봤음에도 가 좋다는 건 알 수 있었다. 하지만 한 가지 의아했던 건 가 버벅거린다는 느낌이 드는 장면이 종종 있었다는 것이다. 망콴족 때문에 말 안 듣는 아이들은 자기들끼리 도망을 쳐야 했고 네이티리는 망콴족의 부족장 바랑이 쏜 활에 크게 다치고 말았다. 그리고 제이크는 쿼리치에게 붙잡히고 말았다. 제이크는 아이들이 무전기도 차지 않았고 스파이더의 마스크도 버려져 있는 걸 보고는 쿼리치에게 아이들을 먼저 구해야 한다고 말했다. 쿼리치는 제 아들에게 의외로 약했던 터라 얼마 동안 손을 잡고 아이들의 행적을 쫓기 시작했다.하지만 목표를 달성한 후에 제이크와 쿼리치는 다시 적으로 돌아갈 수밖에 없었다. 그로 인해 적의 적인 망콴의 바랑과 쿼리치가 손을 잡게 된 건 당연했다. 범죄도시 시리즈를 보는 듯한 감흥 사실 나는 2편도 재미있게 보질 않았다. 3 아이맥스로 봤고 기술력에 감탄하긴 했지만 그게 끝이었다. 영화를 영상미나 로만 보는 게 아닌 사람이라 별 내용이 없음에도 굳이 러닝타임이 3시간이 넘어야 하는지 의문스러웠다. 영화 전개를 위해 어쩔 수 없다 해도 말 안 듣는 아이들로 인해 사건 사고의 연속이라는 점 또한 마음에 들지 않았다.그래서 3편은 굳이 특별관에서 안 봐도 될 거라 생각해 일반 상영관에서 봤고, 가 버벅거릴 때가 있긴 했으나 일반 상영관 스크린으로도 기술력이 뛰어나다는 건 인정이었다. 하지만 역시나 이 이야기를 또 3시간이 넘게 해야 하는지는 회의적이었다. 가족이 죽었는데도 아이들은 여전히 말을 안 들었고, 쿼리치는 전생의 원수라도 되는지 제이크를 포기하질 않았다. 또한 자연과 공생하는 나비족은 선하고 생명체와 자연을 파괴하는 인간은 나쁘다는 의미 또한 전편과 같았다. 물론 도움을 주는 착한 인간이 있었고, 제이크의 가족을 공격하는 망콴족 같은 악당으로 변화를 주긴 했지만 전체적으로 비슷하다는 인상을 지울 수 없었다.그로 인해 영화를 보는 내내 3편을 보는 건지, 2편을 보는 건지 큰 차이가 없다 여겨졌다. 잘라내도 되는 장면이 꽤 있어서 그것만 덜어냈다면 그래도 지금보다는 나았을 텐데, 아쉽게도 좋아하는 영화를 보는 일에 피로감을 느끼고 말았다. 영화를 보며 떠올린 건 범죄도시 시리즈와 아바타 시리즈가 무슨 차이가 있냐는 것이다. 주먹으로 승부하는 형사 마석도가 범죄자를 소탕하는 범죄도시 , 시각적인 즐거움으로 현실에 존재하지 않는 세계에 대해 말하는 아바타 는 내게 큰 차이가 없었다. 시리즈가 전체적으로 패턴화된 것 역시 똑같았기에 전혀 흥미롭지 않았다.그리고 이번 영화에서 가장 아쉬웠던 건 여러 사건을 데우스 엑스 마키나 적으로 해결한 것이었다. 그 중심에 선 키리가 스파이더의 일을 비롯해 마지막 전투까지 다 해결하는 걸 보며 아바타 세계관의 신은 에이와가 아니라 키리인지도 모른다는 생각을 했다. 대부분의 사람들이 12월 최고 기대작으로 뽑았지만 나는 전혀 기대하지 않았던 아바타 불과 재 는 역시나 기대하지 않은 만큼의 인상을 남겼다. 여전한 캐릭터들과 사건 사고의 연속, 그러고선 결말엔 선한 자가 이기는 흐름을 뛰어난 로 덮어버리고 있었다. 영화는 시각적 효과보다 내용이 중요하다 여기는 내게는 아쉽기만 한 영화였지만, 오락 영화를 좋아하는 사람이라면 즐겁게 볼 것 같다.4편이 나올지 안 나올지 모르겠지만, 나온다면 이제 극장에서는 안 보지 않을까 싶다. 덧. 영화 상영 전에 나온 어벤져스 둠스데이 예고편 볼 때 제일 심장이 뛰었음. 아바타 불과 재 , 액션, 모험2025제임스 카메론영화 아바타 불과 재 를 4 3 로 관람했습니다. 2022년 아바타2 물의 길 이 개봉하고 3년만에 개봉한 시리즈 3편입니다. 이번에도 1000만 관객동원이 가능할까 귀추가 주목되고있는데, 현재로는 2편보다 국내 초반 흥행추이가 좀 떨어지는 편인데 장기흥행으로 어떨지 모르겠고, 평가도 이전보단 조금 약한 편이네요. 롯데시네마 월드타워 에서 관람. 아바타3 은 재의 부족 을 새롭게 등장시켰습니다.분노의 불과 슬픔의 재를 바탕으로 이루어진 과격하고 폭력적인 부족이라 할 수 있겠는데,2편 물의 길 이 물 이라는 소재를 강조했다면,3편 불과 재 에선 불 이라는 소재와 이미지를 강조한 작품이라 할 수 있겠네요. 3편 역시 러닝타임이 길어 197분으로 3시간이 훌쩍 넘는데, 제임스 카메론 감독 영화답게 재미는 있어 화장실 한번 안가고 3시간동안 재밌게 봤는데요.그래도 2편보다 아쉬움이 조금 남는 3편이긴 했습니다. 기술력은 발전해.이야기는 반복해. 그 큰 이유로는 반복되는 이야기 구조 때문인 것 같았는데요. 새로운 부족이 등장하긴했지만, 이야기 전개가 2편과 판박이처럼 전개되거나, 도돌이표처럼 본 걸 약간 또 보고있는 느낌?인 것 같더군요. 2,3편을 동시촬영했다고는 하지만.. 2편에서 어느정도 다 싸운 것 같았는데, 쿼리치 대령과 제이크 설리 가족이 스파이더 를 두고 또 싸우고있는 것 같았고, 그 때문에 여러 부족을 또 공격하고 대립하고 이 패턴이 반복되고있는 것 같았고.. 심지어 몇장면은 어, 이 장면 2편에서 본 것 같았는데? 하는 기시감이 자주 들더군요. 그나마 3편에서 큰 변주를 준 건 스파이더 캐릭터를 2편보다 더 적극활용하여, 중요한 요소로 급부상시켜 변수로 작용시켰고 변화를 줬다는 점 이었습니다. 쿼리치 대령의 아들이지만, 설리 가족과 함께 살았고, 3편에선 더 많은 여러가지 변화를 ...

# %% [markdown]
# - 형태소 분석기를 활용하여 문서 -> 토큰화 -> 단어단위로 변경
#   - 키위 형태소 분석기 사용

# %%
# 형태소 분석기 설치
# !pip install kiwipiepy
# Out:
# Collecting kiwipiepy
#   Downloading kiwipiepy-0.22.2-cp39-abi3-win_amd64.whl.metadata (1.3 kB)
# Collecting kiwipiepy_model<0.23,>=0.22 (from kiwipiepy)
#   Downloading kiwipiepy_model-0.22.1.tar.gz (79.5 MB)
#      ---------------------------------------- 0.0/79.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/79.5 MB ? eta -:--:--
#       --------------------------------------- 1.3/79.5 MB 8.9 MB/s eta 0:00:09
#      - -------------------------------------- 2.1/79.5 MB 5.6 MB/s eta 0:00:14
#      -- ------------------------------------- 5.2/79.5 MB 9.2 MB/s eta 0:00:09
#      --- ------------------------------------ 6.8/79.5 MB 8.9 MB/s eta 0:00:09
#      ---- ----------------------------------- 8.7/79.5 MB 8.6 MB/s eta 0:00:09
#      ----- ---------------------------------- 10.2/79.5 MB 8.5 MB/s eta 0:00:09
#      ------- ------------------------------- 15.7/79.5 MB 11.0 MB/s eta 0:00:06
#      --------- ----------------------------- 18.9/79.5 MB 11.5 MB/s eta 0:00:06
#      ----------- --------------------------- 24.1/79.5 MB 13.4 MB/s eta 0:00:05
#      ------------- ------------------------- 27.5/79.5 MB 13.3 MB/s eta 0:00:04
#      ----------------- --------------------- 35.1/79.5 MB 15.4 MB/s eta 0:00:03
#      -------------------- ------------------ 42.5/79.5 MB 17.0 MB/s eta 0:00:03
#      ------------------------ -------------- 49.0/79.5 MB 18.1 MB/s eta 0:00:02
#      ---------------------------- ---------- 57.4/79.5 MB 19.6 MB/s eta 0:00:02
#      -------------------------------- ------ 65.3/79.5 MB 20.8 MB/s eta 0:00:01
#      ----------------------------------- --- 72.1/79.5 MB 21.5 MB/s eta 0:00:01
#      --------------------------------------  79.2/79.5 MB 22.2 MB/s eta 0:00:01
#      --------------------------------------  79.4/79.5 MB 22.2 MB/s eta 0:00:01
#      ---------------------------------------- 79.5/79.5 MB 20.8 MB/s  0:00:04
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\park_kunbeom\anaconda3\lib\site-packages (from kiwipiepy) (2.3.5)
# Requirement already satisfied: tqdm in c:\users\park_kunbeom\anaconda3\lib\site-packages (from kiwipiepy) (4.67.1)
# Requirement already satisfied: colorama in c:\users\park_kunbeom\anaconda3\lib\site-packages (from tqdm->kiwipiepy) (0.4.6)
# Downloading kiwipiepy-0.22.2-cp39-abi3-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 28.8 MB/s  0:00:00
# Building wheels for collected packages: kiwipiepy_model
#   Building wheel for kiwipiepy_model (pyproject.toml): started
#   Building wheel for kiwipiepy_model (pyproject.toml): finished with status 'done'
#   Created wheel for kiwipiepy_model: filename=kiwipiepy_model-0.22.1-py3-none-any.whl size=79578176 sha256=3d6042ed4900c7df3f84400c3ea8ba341c9bc19ae772aea05b43317fa4df8fd6
#   Stored in directory: c:\users\park_kunbeom\appdata\local\pip\cache\wheels\c2\cd\69\f6ec7f41232d2e0aeb74cfc3ee09cb16cea8a4abdbcd30a271
# Successfully built kiwipiepy_model
# Installing collected packages: kiwipiepy_model, kiwipiepy
#
#    ---------------------------------------- 0/2 [kiwipiepy_model]
#    ---------------------------------------- 0/2 [kiwipiepy_model]
#    ---------------------------------------- 0/2 [kiwipiepy_model]
#    ---------------------------------------- 0/2 [kiwipiepy_model]
#    -------------------- ------------------- 1/2 [kiwipiepy]
#    ---------------------------------------- 2/2 [kiwipiepy]
#
# Successfully installed kiwipiepy-0.22.2 kiwipiepy_model-0.22.1

# %%
# 워드클라우드 생성 도구 설치
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.5-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.19 in c:\users\park_kunbeom\anaconda3\lib\site-packages (from wordcloud) (2.3.5)
# Requirement already satisfied: pillow in c:\users\park_kunbeom\anaconda3\lib\site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: matplotlib in c:\users\park_kunbeom\anaconda3\lib\site-packages (from wordcloud) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\park_kunbeom\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\park_kunbeom\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\park_kunbeom\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\park_kunbeom\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\park_kunbeom\anaconda3\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\park_kunbeom\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\park_kunbeom\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\park_kunbeom\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.5-cp313-cp313-win_amd64.whl (307 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.5

# %%
# 라이브러리 불러오기
from kiwipiepy import Kiwi # 키위 형태소 분석기
from wordcloud import WordCloud # 워드클라우드 생성 도구
from collections import Counter # 단어가 나온 횟수를 세주는 도구
import matplotlib.pyplot as plt #t시각화도구

# %%
# 도구 객체생성
kiwi = Kiwi()
# 토큰화
token = kiwi.tokenize(review)

# %%
token
# Out:
# [Token(form='영화', tag='NNG', start=0, len=2),
#  Token(form='아바타', tag='NNP', start=3, len=3),
#  Token(form='불과', tag='MAG', start=7, len=2),
#  Token(form='재', tag='XPN', start=10, len=1),
#  Token(form='정보', tag='NNG', start=12, len=2),
#  Token(form=',', tag='SP', start=14, len=1),
#  Token(form='줄거리', tag='NNG', start=16, len=3),
#  Token(form=',', tag='SP', start=19, len=1),
#  Token(form='리뷰', tag='NNG', start=21, len=2),
#  Token(form='영화', tag='NNG', start=24, len=2),
#  Token(form='정보', tag='NNG', start=27, len=2),
#  Token(form='기본', tag='NNG', start=30, len=2),
#  Token(form='정보', tag='NNG', start=33, len=2),
#  Token(form='원', tag='NNG', start=36, len=1),
#  Token(form='제', tag='XSN', start=37, len=1),
#  Token(form='수입', tag='NNG', start=39, len=2),
#  Token(form='배급', tag='NNG', start=42, len=2),
#  Token(form='월트', tag='NNP', start=45, len=2),
#  Token(form='디즈니', tag='NNP', start=47, len=3),
#  Token(form='컴퍼니', tag='NNG', start=51, len=3),
#  Token(form='코리아', tag='NNP', start=55, len=3),
#  Token(form='감독', tag='NNG', start=58, len=2),
#  Token(form='제임스', tag='NNP', start=61, len=3),
#  Token(form='카메론', tag='NNP', start=65, len=3),
#  Token(form='출연', tag='NNG', start=68, len=2),
#  Token(form='샘', tag='NNP', start=71, len=1),
#  Token(form='워싱턴', tag='NNP', start=73, len=3),
#  Token(form=',', tag='SP', start=76, len=1),
#  Token(form='조이 살다나', tag='NNP', start=78, len=6),
#  Token(form=',', tag='SP', start=84, len=1),
#  Token(form='시고니 위버', tag='NNP', start=86, len=6),
#  Token(form=',', tag='SP', start=92, len=1),
#  Token(form='스티븐', tag='NNP', start=94, len=3),
#  Token(form='랭', tag='NNP', start=98, len=1),
#  Token(form=',', tag='SP', start=99, len=1),
#  Token(form='우나 채플린', tag='NNP', start=101, len=6),
#  Token(form=',', tag='SP', start=107, len=1),
#  Token(form='케이트 윈슬렛', tag='NNP', start=109, len=7),
#  Token(form='외', tag='NNB', start=117, len=1),
#  Token(form='제작', tag='NNG', start=118, len=2),
#  Token(form='국가', tag='NNG', start=121, len=2),
#  Token(form='미국', tag='NNP', start=124, len=2),
#  Token(form='장르', tag='NNG', start=126, len=2),
#  Token(form='액션', tag='NNG', start=129, len=2),
#  Token(form=',', tag='SP', start=131, len=1),
#  Token(form='어드벤처', tag='NNP', start=133, len=4),
#  Token(form='모험', tag='NNG', start=138, len=2),
#  Token(form=',', tag='SP', start=141, len=1),
#  Token(form='판타지', tag='NNG', start=143, len=3),
#  Token(form=',', tag='SP', start=146, len=1),
#  Token(form=',', tag='SP', start=148, len=1),
#  Token(form='스릴러', tag='NNG', start=150, len=3),
#  Token(form='관람', tag='NNG', start=153, len=2),
#  Token(form='등급', tag='NNG', start=156, len=2),
#  Token(form='12', tag='SN', start=159, len=2),
#  Token(form='세', tag='NNB', start=161, len=1),
#  Token(form='이상', tag='NNG', start=163, len=2),
#  Token(form='관람', tag='NNG', start=166, len=2),
#  Token(form='가', tag='NNG', start=168, len=1),
#  Token(form='상영', tag='NNG', start=169, len=2),
#  Token(form='시간', tag='NNG', start=172, len=2),
#  Token(form='195', tag='SN', start=175, len=3),
#  Token(form='분', tag='NNB', start=178, len=1),
#  Token(form='극장', tag='NNG', start=179, len=2),
#  Token(form='개봉', tag='NNG', start=182, len=2),
#  Token(form='2025', tag='SN', start=185, len=4),
#  Token(form='년', tag='NNB', start=189, len=1),
#  Token(form='12', tag='SN', start=191, len=2),
#  Token(form='월', tag='NNB', start=193, len=1),
#  Token(form='17', tag='SN', start=195, len=2),
#  Token(form='일', tag='NNB', start=197, len=1),
#  Token(form='줄거리', tag='NNG', start=199, len=3),
#  Token(form='크', tag='VA', start=203, len=1),
#  Token(form='ᆫ', tag='ETM', start=203, len=1),
#  Token(form='아들', tag='NNG', start=204, len=2),
#  Token(form='을', tag='JKO', start=206, len=1),
#  Token(form='잃', tag='VV', start=208, len=1),
#  Token(form='은', tag='ETM', start=209, len=1),
#  Token(form='제이크 설리', tag='NNP', start=211, len=6),
#  Token(form='와', tag='JC', start=217, len=1),
#  Token(form='네이티리', tag='NNP', start=219, len=4),
#  Token(form='가족', tag='NNG', start=224, len=2),
#  Token(form='은', tag='JX', start=226, len=1),
#  Token(form='저마다', tag='MAG', start=228, len=3),
#  Token(form='애도', tag='NNG', start=232, len=2),
#  Token(form='를', tag='JKO', start=234, len=1),
#  Token(form='하', tag='VV', start=236, len=1),
#  Token(form='고', tag='EC', start=237, len=1),
#  Token(form='있', tag='VX', start=239, len=1),
#  Token(form='다', tag='EF', start=240, len=1),
#  Token(form='.', tag='SF', start=241, len=1),
#  Token(form='그러', tag='VV', start=243, len=2),
#  Token(form='던', tag='ETM', start=245, len=1),
#  Token(form='중', tag='NNB', start=247, len=1),
#  Token(form='그', tag='NP', start=249, len=1),
#  Token(form='들', tag='XSN', start=250, len=1),
#  Token(form='가족', tag='NNG', start=252, len=2),
#  Token(form='에게', tag='JKB', start=254, len=2),
#  Token(form='다시', tag='MAG', start=257, len=2),
#  Token(form='위기', tag='NNG', start=260, len=2),
#  Token(form='가', tag='JKS', start=262, len=1),
#  Token(form='찾아오', tag='VV', start=264, len=3),
#  Token(form='는데', tag='EC', start=267, len=2),
#  Token(form='...', tag='SF', start=269, len=3),
#  Token(form='리뷰', tag='NNG', start=273, len=2),
#  Token(form='로', tag='JKB', start=275, len=1),
#  Token(form='보', tag='VV', start=277, len=1),
#  Token(form='는', tag='ETM', start=278, len=1),
#  Token(form='관람', tag='NNG', start=280, len=2),
#  Token(form='포인트', tag='NNG', start=283, len=3),
#  Token(form='여전히', tag='MAG', start=287, len=3),
#  Token(form='말', tag='NNG', start=291, len=1),
#  Token(form='안', tag='MAG', start=293, len=1),
#  Token(form='듣', tag='VV-I', start=295, len=1),
#  Token(form='는', tag='ETM', start=296, len=1),
#  Token(form='아이', tag='NNG', start=298, len=2),
#  Token(form='들', tag='XSN', start=300, len=1),
#  Token(form='3', tag='SN', start=302, len=1),
#  Token(form='편', tag='NNB', start=303, len=1),
#  Token(form='을', tag='JKO', start=304, len=1),
#  Token(form='보', tag='VV', start=306, len=1),
#  Token(form='기', tag='ETN', start=307, len=1),
#  Token(form='위하', tag='VV', start=309, len=2),
#  Token(form='어', tag='EC', start=310, len=1),
#  Token(form='굳이', tag='MAG', start=312, len=2),
#  Token(form='2', tag='SN', start=315, len=1),
#  Token(form='편', tag='NNB', start=316, len=1),
#  Token(form='을', tag='JKO', start=317, len=1),
#  Token(form='복습', tag='NNG', start=319, len=2),
#  Token(form='하', tag='XSV', start=321, len=1),
#  Token(form='지', tag='EC', start=322, len=1),
#  Token(form='않', tag='VX', start=324, len=1),
#  Token(form='어도', tag='EC', start=325, len=2),
#  Token(form='되', tag='VV', start=328, len=1),
#  Token(form='ᆯ', tag='ETM', start=328, len=1),
#  Token(form='것', tag='NNB', start=330, len=1),
#  Token(form='같', tag='VA', start=332, len=1),
#  Token(form='어', tag='EC', start=333, len=1),
#  Token(form='일단', tag='MAG', start=335, len=2),
#  Token(form='보', tag='VV', start=338, len=1),
#  Token(form='기', tag='ETN', start=339, len=1),
#  Token(form='시작', tag='NNG', start=341, len=2),
#  Token(form='하', tag='XSV', start=343, len=1),
#  Token(form='ᆫ', tag='ETM', start=343, len=1),
#  Token(form='영화', tag='NNG', start=345, len=2),
#  Token(form='오프닝', tag='NNG', start=348, len=3),
#  Token(form='에서', tag='JKB', start=351, len=2),
#  Token(form='는', tag='JX', start=353, len=1),
#  Token(form='전편', tag='NNG', start=355, len=2),
#  Token(form='에서', tag='JKB', start=357, len=2),
#  Token(form='사망', tag='NNG', start=360, len=2),
#  Token(form='하', tag='XSV', start=362, len=1),
#  Token(form='ᆫ', tag='ETM', start=362, len=1),
#  Token(form='네테이얌이', tag='NNP', start=364, len=5),
#  Token(form='등장', tag='NNG', start=370, len=2),
#  Token(form='하', tag='XSV', start=372, len=1),
#  Token(form='어', tag='EC', start=372, len=1),
#  Token(form='로아크', tag='NNP', start=374, len=3),
#  Token(form='와', tag='JKB', start=377, len=1),
#  Token(form='자유', tag='NNG', start=379, len=2),
#  Token(form='롭', tag='XSA-I', start=381, len=1),
#  Token(form='게', tag='EC', start=382, len=1),
#  Token(form='비행', tag='NNG', start=384, len=2),
#  Token(form='을', tag='JKO', start=386, len=1),
#  Token(form='하', tag='VV', start=388, len=1),
#  Token(form='는', tag='ETM', start=389, len=1),
#  Token(form='모습', tag='NNG', start=391, len=2),
#  Token(form='을', tag='JKO', start=393, len=1),
#  Token(form='보이', tag='VV', start=395, len=2),
#  Token(form='어', tag='EC', start=396, len=1),
#  Token(form='주', tag='VX', start=397, len=1),
#  Token(form='었', tag='EP', start=397, len=1),
#  Token(form='다', tag='EF', start=398, len=1),
#  Token(form='.', tag='SF', start=399, len=1),
#  Token(form='나비', tag='NNG', start=401, len=2),
#  Token(form='족', tag='NNG', start=403, len=1),
#  Token(form='만', tag='JX', start=404, len=1),
#  Token(form='이', tag='JKS', start=405, len=1),
#  Token(form='하', tag='VV', start=407, len=1),
#  Token(form='ᆯ', tag='ETM', start=407, len=1),
#  Token(form='수', tag='NNB', start=409, len=1),
#  Token(form='있', tag='VA', start=411, len=1),
#  Token(form='는', tag='ETM', start=412, len=1),
#  Token(form='의식', tag='NNG', start=414, len=2),
#  Token(form='같', tag='VA', start=417, len=1),
#  Token(form='은', tag='ETM', start=418, len=1),
#  Token(form='거', tag='NNB', start=420, len=1),
#  Token(form='ᆯ로', tag='JKB', start=420, len=2),
#  Token(form='로아크', tag='NNP', start=423, len=3),
#  Token(form='는', tag='JX', start=426, len=1),
#  Token(form='죽', tag='VV', start=428, len=1),
#  Token(form='은', tag='ETM', start=429, len=1),
#  Token(form='형', tag='NNG', start=431, len=1),
#  Token(form='과', tag='JKB', start=432, len=1),
#  Token(form='대화', tag='NNG', start=434, len=2),
#  Token(form='하', tag='XSV', start=436, len=1),
#  Token(form='며', tag='EC', start=437, len=1),
#  Token(form='즐겁', tag='VA-I', start=439, len=3),
#  Token(form='은', tag='ETM', start=441, len=1),
#  Token(form='시간', tag='NNG', start=443, len=2),
#  Token(form='을', tag='JKO', start=445, len=1),
#  Token(form='보내', tag='VV', start=447, len=2),
#  Token(form='ᆯ', tag='ETM', start=448, len=1),
#  Token(form='수', tag='NNB', start=450, len=1),
#  Token(form='있', tag='VA', start=452, len=1),
#  Token(form='던', tag='ETM', start=453, len=1),
#  Token(form='것', tag='NNB', start=455, len=1),
#  Token(form='이', tag='VCP', start=456, len=1),
#  Token(form='었', tag='EP', start=457, len=1),
#  Token(form='다', tag='EF', start=458, len=1),
#  Token(form='.', tag='SF', start=459, len=1),
#  Token(form='로아크', tag='NNP', start=460, len=3),
#  Token(form='가', tag='JKS', start=463, len=1),
#  Token(form='자신', tag='NNG', start=465, len=2),
#  Token(form='만', tag='JX', start=467, len=1),
#  Token(form='의', tag='JKG', start=468, len=1),
#  Token(form='방식', tag='NNG', start=470, len=2),
#  Token(form='으로', tag='JKB', start=472, len=2),
#  Token(form='형', tag='NNG', start=475, len=1),
#  Token(form='을', tag='JKO', start=476, len=1),
#  Token(form='그리워하', tag='VV', start=478, len=4),
#  Token(form='고', tag='EC', start=482, len=1),
#  Token(form='있', tag='VX', start=484, len=1),
#  Token(form='을', tag='ETM', start=485, len=1),
#  Token(form='때', tag='NNG', start=487, len=1),
#  Token(form='엄마', tag='NNG', start=489, len=2),
#  Token(form='이', tag='VCP', start=491, len=1),
#  Token(form='ᆫ', tag='ETM', start=491, len=1),
#  Token(form='네이티리', tag='NNP', start=493, len=4),
#  Token(form='는', tag='JX', start=497, len=1),
#  Token(form='상실감', tag='NNG', start=499, len=3),
#  Token(form='에', tag='JKB', start=502, len=1),
#  Token(form='아무것', tag='NNG', start=504, len=3),
#  Token(form='도', tag='JX', start=507, len=1),
#  Token(form='하', tag='VV', start=509, len=1),
#  Token(form='지', tag='EC', start=510, len=1),
#  Token(form='못하', tag='VX', start=512, len=2),
#  Token(form='고', tag='EC', start=514, len=1),
#  Token(form='슬퍼하', tag='VV', start=516, len=3),
#  Token(form='기', tag='ETN', start=519, len=1),
#  Token(form='만', tag='JX', start=520, len=1),
#  Token(form='하', tag='VX', start=522, len=1),
#  Token(form='었', tag='EP', start=522, len=1),
#  Token(form='다', tag='EF', start=523, len=1),
#  Token(form='.', tag='SF', start=524, len=1),
#  Token(form='그리고', tag='MAJ', start=526, len=3),
#  Token(form='설리', tag='NNP', start=530, len=2),
#  Token(form='는', tag='JX', start=532, len=1),
#  Token(form='인간', tag='NNG', start=534, len=2),
#  Token(form='이', tag='JKS', start=536, len=1),
#  Token(form='다시금', tag='MAG', start=538, len=3),
#  Token(form='공격', tag='NNG', start=542, len=2),
#  Token(form='을', tag='JKO', start=544, len=1),
#  Token(form='하', tag='VV', start=546, len=1),
#  Token(form='어', tag='EC', start=546, len=1),
#  Token(form='오', tag='VX', start=547, len=1),
#  Token(form='ᆯ', tag='ETM', start=547, len=1),
#  Token(form='거', tag='NNB', start=549, len=1),
#  Token(form='ᆯ', tag='JKO', start=549, len=1),
#  Token(form='예상', tag='NNG', start=551, len=2),
#  Token(form='하', tag='XSV', start=553, len=1),
#  Token(form='어', tag='EC', start=553, len=1),
#  Token(form='바다', tag='NNG', start=555, len=2),
#  Token(form='에', tag='JKB', start=557, len=1),
#  Token(form='가라앉', tag='VV', start=559, len=3),
#  Token(form='은', tag='ETM', start=562, len=1),
#  Token(form='인간', tag='NNG', start=564, len=2),
#  Token(form='들', tag='XSN', start=566, len=1),
#  Token(form='의', tag='JKG', start=567, len=1),
#  Token(form='전함', tag='NNG', start=569, len=2),
#  Token(form='에서', tag='JKB', start=571, len=2),
#  Token(form='총', tag='NNG', start=574, len=1),
#  Token(form='을', tag='JKO', start=575, len=1),
#  Token(form='비롯', tag='XR', start=577, len=2),
#  Token(form='하', tag='XSV', start=579, len=1),
#  Token(form='ᆫ', tag='ETM', start=579, len=1),
#  Token(form='각종', tag='NNG', start=581, len=2),
#  Token(form='무기', tag='NNG', start=584, len=2),
#  Token(form='를', tag='JKO', start=586, len=1),
#  Token(form='모으', tag='VV', start=588, len=2),
#  Token(form='기', tag='ETN', start=590, len=1),
#  Token(form='시작', tag='NNG', start=592, len=2),
#  Token(form='하', tag='XSV', start=594, len=1),
#  Token(form='었', tag='EP', start=594, len=1),
#  Token(form='다', tag='EF', start=595, len=1),
#  Token(form='.', tag='SF', start=596, len=1),
#  Token(form='설리', tag='NNP', start=598, len=2),
#  Token(form='네', tag='XSN', start=600, len=1),
#  Token(form='가족', tag='NNG', start=602, len=2),
#  Token(form='이', tag='JKS', start=604, len=1),
#  Token(form='의지', tag='NNG', start=606, len=2),
#  Token(form='하', tag='XSV', start=608, len=1),
#  Token(form='고', tag='EC', start=609, len=1),
#  Token(form='있', tag='VX', start=611, len=1),
#  Token(form='는', tag='ETM', start=612, len=1),
#  Token(form='멧카이나', tag='NNP', start=614, len=4),
#  Token(form='의', tag='JKG', start=618, len=1),
#  Token(form='부족장', tag='NNG', start=620, len=3),
#  Token(form='은', tag='JX', start=623, len=1),
#  Token(form='강하', tag='VA', start=625, len=2),
#  Token(form='게', tag='EC', start=627, len=1),
#  Token(form='반발', tag='NNG', start=629, len=2),
#  Token(form='하', tag='XSV', start=631, len=1),
#  Token(form='었', tag='EP', start=631, len=1),
#  Token(form='지만', tag='EC', start=632, len=2),
#  Token(form='설리', tag='NNP', start=635, len=2),
#  Token(form='는', tag='JX', start=637, len=1),
#  Token(form='뜻', tag='NNG', start=639, len=1),
#  Token(form='을', tag='JKO', start=640, len=1),
#  Token(form='굽히', tag='VV', start=642, len=2),
#  Token(form='지', tag='EC', start=644, len=1),
#  Token(form='않', tag='VX', start=646, len=1),
#  Token(form='었', tag='EP', start=647, len=1),
#  Token(form='다', tag='EF', start=648, len=1),
#  Token(form='.', tag='SF', start=649, len=1),
#  Token(form='그러', tag='VV', start=651, len=2),
#  Token(form='던', tag='ETM', start=653, len=1),
#  Token(form='중', tag='NNB', start=655, len=1),
#  Token(form='에', tag='JKB', start=656, len=1),
#  Token(form='제이크', tag='NNP', start=658, len=3),
#  Token(form='는', tag='JX', start=661, len=1),
#  Token(form='인간', tag='NNG', start=663, len=2),
#  Token(form='이', tag='VCP', start=665, len=1),
#  Token(form='ᆫ', tag='ETM', start=665, len=1),
#  Token(form='스파이더', tag='NNP', start=667, len=4),
#  Token(form='를', tag='JKO', start=671, len=1),
#  Token(form='바람', tag='NNG', start=673, len=2),
#  Token(form='상인', tag='NNG', start=676, len=2),
#  Token(form='의', tag='JKG', start=678, len=1),
#  Token(form='편', tag='NNG', start=680, len=1),
#  Token(form='에', tag='JKB', start=681, len=1),
#  Token(form='보내', tag='VV', start=683, len=2),
#  Token(form='려고', tag='EC', start=685, len=2),
#  Token(form='하', tag='VX', start=688, len=1),
#  Token(form='었', tag='EP', start=688, len=1),
#  Token(form='다', tag='EF', start=689, len=1),
#  Token(form='.', tag='SF', start=690, len=1),
#  Token(form='스파이더', tag='NNP', start=692, len=4),
#  Token(form='가', tag='JKS', start=696, len=1),
#  Token(form='쿼리치', tag='NNP', start=698, len=3),
#  Token(form='의', tag='JKG', start=701, len=1),
#  Token(form='아들', tag='NNG', start=703, len=2),
#  Token(form='이', tag='VCP', start=705, len=1),
#  Token(form='었', tag='EP', start=706, len=1),
#  Token(form='기에', tag='EC', start=707, len=2),
#  Token(form='데리', tag='VV', start=710, len=2),
#  Token(form='고', tag='EC', start=712, len=1),
#  Token(form='있', tag='VX', start=714, len=1),
#  Token(form='으면', tag='EC', start=715, len=2),
#  Token(form='그', tag='NP', start=718, len=1),
#  Token(form='가', tag='JKS', start=719, len=1),
#  Token(form='언제', tag='NP', start=721, len=2),
#  Token(form='이', tag='VCP', start=723, len=0),
#  Token(form='든', tag='EC', start=723, len=1),
#  Token(form='다시', tag='MAG', start=725, len=2),
#  Token(form='공격', tag='NNG', start=728, len=2),
#  Token(form='하', tag='XSV', start=730, len=1),
#  Token(form='어', tag='EC', start=730, len=1),
#  Token(form='오', tag='VX', start=731, len=1),
#  Token(form='ᆯ', tag='ETM', start=731, len=1),
#  Token(form='수', tag='NNB', start=733, len=1),
#  Token(form='있', tag='VA', start=735, len=1),
#  Token(form='었', tag='EP', start=736, len=1),
#  Token(form='기', tag='ETN', start=737, len=1),
#  Token(form='때문', tag='NNB', start=739, len=2),
#  Token(form='이', tag='VCP', start=741, len=1),
#  Token(form='었', tag='EP', start=742, len=1),
#  Token(form='다', tag='EF', start=743, len=1),
#  Token(form='.', tag='SF', start=744, len=1),
#  Token(form='스파이더', tag='NNG', start=746, len=4),
#  Token(form='는', tag='JX', start=750, len=1),
#  Token(form='강하', tag='VA', start=752, len=2),
#  Token(form='게', tag='EC', start=754, len=1),
#  Token(form='반발', tag='NNG', start=756, len=2),
#  Token(form='하', tag='XSV', start=758, len=1),
#  Token(form='었', tag='EP', start=758, len=1),
#  Token(form='고', tag='EC', start=759, len=1),
#  Token(form=',', tag='SP', start=760, len=1),
#  Token(form='설리', tag='NNP', start=762, len=2),
#  Token(form='의', tag='JKG', start=764, len=1),
#  Token(form='아이', tag='NNG', start=766, len=2),
#  Token(form='들', tag='XSN', start=768, len=1),
#  Token(form='까지', tag='JX', start=769, len=2),
#  Token(form='도', tag='JX', start=771, len=1),
#  Token(form='가족', tag='NNG', start=773, len=2),
#  Token(form='이', tag='VCP', start=775, len=1),
#  Token(form='라며', tag='EC', start=776, len=2),
#  Token(form='보내', tag='VV', start=779, len=2),
#  Token(form='면', tag='EC', start=781, len=1),
#  Token(form='안', tag='MAG', start=783, len=1),
#  Token(form='되', tag='VV', start=785, len=1),
#  Token(form='ᆫ다고', tag='EC', start=785, len=3),
#  Token(form='하', tag='VV', start=789, len=1),
#  Token(form='었', tag='EP', start=789, len=1),
#  Token(form='지만', tag='EC', start=790, len=2),
#  Token(form='부모', tag='NNG', start=793, len=2),
#  Token(form='의', tag='JKG', start=795, len=1),
#  Token(form='뜻', tag='NNG', start=797, len=1),
#  Token(form='을', tag='JKO', start=798, len=1),
#  Token(form='꺾', tag='VV', start=800, len=1),
#  Token(form='을', tag='ETM', start=801, len=1),
#  Token(form='수', tag='NNB', start=803, len=1),
#  Token(form='는', tag='JX', start=804, len=1),
#  Token(form='없', tag='VA', start=806, len=1),
#  Token(form='었', tag='EP', start=807, len=1),
#  Token(form='다', tag='EF', start=808, len=1),
#  Token(form='.', tag='SF', start=809, len=1),
#  Token(form='그나마', tag='MAG', start=811, len=3),
#  Token(form='함께', tag='MAG', start=815, len=2),
#  Token(form='가', tag='VV', start=818, len=1),
#  Token(form='어서', tag='EC', start=818, len=2),
#  Token(form='데리', tag='VV', start=821, len=2),
#  Token(form='어다', tag='EC', start=822, len=2),
#  Token(form='주', tag='VX', start=824, len=1),
#  Token(form='고', tag='EC', start=825, len=1),
#  Token(form='오', tag='VV', start=827, len=1),
#  Token(form='자는', tag='ETM', start=828, len=2),
#  Token(form='의견', tag='NNG', start=831, len=2),
#  Token(form='으로', tag='JKB', start=833, len=2),
#  Token(form='분위기', tag='NNG', start=836, len=3),
#  Token(form='가', tag='JKS', start=839, len=1),
#  Token(form='조금', tag='MAG', start=841, len=2),
#  Token(form='누그러지', tag='VV', start=844, len=4),
#  Token(form='었', tag='EP', start=847, len=1),
#  Token(form='다', tag='EF', start=848, len=1),
#  Token(form='.', tag='SF', start=849, len=1),
#  Token(form='바람', tag='NNG', start=851, len=2),
#  Token(form='상인', tag='NNG', start=854, len=2),
#  Token(form='과', tag='JKB', start=856, len=1),
#  Token(form='함께', tag='MAG', start=858, len=2),
#  Token(form='떠나', tag='VV', start=861, len=2),
#  Token(form='게', tag='EC', start=863, len=1),
#  Token(form='되', tag='VV', start=865, len=1),
#  Token(form='ᆫ', tag='ETM', start=865, len=1),
#  Token(form='설리', tag='NNP', start=867, len=2),
#  Token(form='의', tag='JKG', start=869, len=1),
#  Token(form='가족', tag='NNG', start=871, len=2),
#  Token(form='은', tag='JX', start=873, len=1),
#  Token(form='시작', tag='NNG', start=875, len=2),
#  Token(form='부터', tag='JX', start=877, len=2),
#  Token(form='불안', tag='NNG', start=880, len=2),
#  Token(form='불안', tag='NNG', start=882, len=2),
#  Token(form='하', tag='XSA', start=884, len=1),
#  Token(form='기', tag='ETN', start=885, len=1),
#  Token(form='만', tag='JX', start=886, len=1),
#  Token(form='하', tag='VX', start=888, len=1),
#  Token(form='었', tag='EP', start=888, len=1),
#  Token(form='다', tag='EF', start=889, len=1),
#  Token(form='.', tag='SF', start=890, len=1),
#  Token(form='이', tag='MM', start=892, len=1),
#  Token(form='사건', tag='NNG', start=894, len=2),
#  Token(form='이전', tag='NNG', start=897, len=2),
#  Token(form='에', tag='JKB', start=899, len=1),
#  Token(form='스파이더', tag='NNP', start=901, len=4),
#  Token(form='가', tag='JKS', start=905, len=1),
#  Token(form='자', tag='VV', start=907, len=1),
#  Token(form='던', tag='ETM', start=908, len=1),
#  Token(form='중', tag='NNB', start=910, len=1),
#  Token(form='에', tag='JKB', start=911, len=1),
#  Token(form='마스크', tag='NNG', start=913, len=3),
#  Token(form='에', tag='JKB', start=916, len=1),
#  Token(form='문제', tag='NNG', start=918, len=2),
#  Token(form='가', tag='JKS', start=920, len=1),
#  Token(form='생기', tag='VV', start=922, len=2),
#  Token(form='어', tag='EC', start=923, len=1),
#  Token(form='죽', tag='VV', start=925, len=1),
#  Token(form='을', tag='ETM', start=926, len=1),
#  Token(form='뻔', tag='NNB', start=928, len=1),
#  Token(form='하', tag='XSA', start=929, len=1),
#  Token(form='었', tag='EP', start=929, len=1),
#  Token(form='었', tag='EP', start=930, len=1),
#  Token(form='고', tag='EC', start=931, len=1),
#  Token(form=',', tag='SP', start=932, len=1),
#  Token(form='설리', tag='NNP', start=934, len=2),
#  Token(form='가', tag='JKS', start=936, len=1),
#  Token(form='로아크', tag='NNP', start=938, len=3),
#  Token(form='에게', tag='JKB', start=941, len=2),
#  Token(form='무전기', tag='NNG', start=944, len=3),
#  Token(form='를', tag='JKO', start=947, len=1),
#  Token(form='차', tag='VV', start=949, len=1),
#  Token(form='어야', tag='EC', start=949, len=2),
#  Token(form='하', tag='VX', start=952, len=1),
#  Token(form='ᆫ다고', tag='EC', start=952, len=3),
#  Token(form='하', tag='VV', start=956, len=1),
#  Token(form='었', tag='EP', start=956, len=1),
#  Token(form='던', tag='ETM', start=957, len=1),
#  Token(form='적', tag='NNB', start=959, len=1),
#  Token(form='이', tag='JKS', start=960, len=1),
#  Token(form='있', tag='VV', start=962, len=1),
#  Token(form='었', tag='EP', start=963, len=1),
#  Token(form='다', tag='EF', start=964, len=1),
#  Token(form='.', tag='SF', start=965, len=1),
#  Token(form='하지만', tag='MAJ', start=967, len=3),
#  Token(form='이', tag='MM', start=971, len=1),
#  Token(form='두', tag='MM', start=973, len=1),
#  Token(form='아이', tag='NNG', start=975, len=2),
#  Token(form='들', tag='XSN', start=977, len=1),
#  Token(form='은', tag='JX', start=978, len=1),
#  Token(form='당연히', tag='MAG', start=980, len=3),
#  Token(form='말', tag='NNG', start=984, len=1),
#  Token(form='을', tag='JKO', start=985, len=1),
#  Token(form='안', tag='MAG', start=987, len=1),
#  Token(form='듣', tag='VV-I', start=989, len=1),
#  Token(form='었', tag='EP', start=990, len=1),
#  Token(form='다', tag='EF', start=991, len=1),
#  Token(form='.', tag='SF', start=992, len=1),
#  Token(form='전편', tag='NNG', start=994, len=2),
#  Token(form='에서', tag='JKB', start=996, len=2),
#  Token(form='말', tag='NNG', start=999, len=1),
#  Token(form='안', tag='MAG', start=1001, len=1),
#  Token(form='듣', tag='VV-I', start=1003, len=1),
#  Token(form='는', tag='ETM', start=1004, len=1),
#  Token(form='아이', tag='NNG', start=1006, len=2),
#  Token(form='들', tag='XSN', start=1008, len=1),
#  Token(form='때문', tag='NNB', start=1010, len=2),
#  Token(form='에', tag='JKB', start=1012, len=1),
#  Token(form='짜증', tag='NNG', start=1014, len=2),
#  Token(form='나', tag='VV', start=1017, len=1),
#  Token(form='었', tag='EP', start=1017, len=1),
#  Token(form='던', tag='ETM', start=1018, len=1),
#  Token(form='기억', tag='NNG', start=1020, len=2),
#  Token(form='이', tag='JKS', start=1022, len=1),
#  Token(form='남', tag='VV', start=1024, len=1),
#  Token(form='어', tag='EC', start=1025, len=1),
#  Token(form='있', tag='VX', start=1027, len=1),
#  Token(form='는데', tag='EC', start=1028, len=2),
#  Token(form=',', tag='SP', start=1030, len=1),
#  Token(form='이번', tag='NNG', start=1032, len=2),
#  Token(form='에', tag='JKB', start=1034, len=1),
#  Token(form='도', tag='JX', start=1035, len=1),
#  Token(form='그러', tag='VV', start=1037, len=2),
#  Token(form='니', tag='EC', start=1039, len=1),
#  Token(form='어처구니', tag='NNG', start=1041, len=4),
#  Token(form='가', tag='JKS', start=1045, len=1),
#  Token(form='없', tag='VA', start=1047, len=1),
#  Token(form='었', tag='EP', start=1048, len=1),
#  Token(form='다', tag='EF', start=1049, len=1),
#  Token(form='.', tag='SF', start=1050, len=1),
#  Token(form='네테이얌', tag='NNP', start=1052, len=4),
#  Token(form='이', tag='XSN', start=1056, len=1),
#  Token(form='죽', tag='VV', start=1058, len=1),
#  Token(form='고서', tag='EC', start=1059, len=2),
#  Token(form='도', tag='JX', start=1061, len=1),
#  Token(form='정신', tag='NNG', start=1063, len=2),
#  Token(form='을', tag='JKO', start=1065, len=1),
#  Token(form='못', tag='MAG', start=1067, len=1),
#  Token(form='차리', tag='VV', start=1069, len=2),
#  Token(form='었', tag='EP', start=1070, len=1),
#  Token(form='다', tag='EC', start=1071, len=1),
#  Token(form='싶', tag='VX', start=1073, len=1),
#  Token(form='었', tag='EP', start=1074, len=1),
#  Token(form='기', tag='ETN', start=1075, len=1),
#  Token(form='때문', tag='NNB', start=1077, len=2),
#  Token(form='이', tag='VCP', start=1079, len=1),
#  Token(form='다', tag='EF', start=1080, len=1),
#  Token(form='.', tag='SF', start=1081, len=1),
#  Token(form='이후', tag='NNG', start=1082, len=2),
#  Token(form='영화', tag='NNG', start=1085, len=2),
#  Token(form='후반', tag='NNG', start=1088, len=2),
#  Token(form='으로', tag='JKB', start=1090, len=2),
#  Token(form='가', tag='VV', start=1093, len=1),
#  Token(form='면서', tag='EC', start=1094, len=2),
#  Token(form='키리', tag='NNG', start=1097, len=2),
#  Token(form='역시', tag='MAG', start=1100, len=2),
#  Token(form='형제', tag='NNG', start=1103, len=2),
#  Token(form='들', tag='XSN', start=1105, len=1),
#  Token(form='이', tag='JKS', start=1106, len=1),
#  Token(form='말리', tag='VV', start=1108, len=2),
#  Token(form='는', tag='ETM', start=1110, len=1),
#  Token(form='데', tag='NNB', start=1112, len=1),
#  Token(form='도', tag='JX', start=1113, len=1),
#  Token(form='자신', tag='NNG', start=1115, len=2),
#  Token(form='의', tag='JKG', start=1117, len=1),
#  Token(form='뜻', tag='NNG', start=1119, len=1),
#  Token(form='대로', tag='JX', start=1120, len=2),
#  Token(form='행동', tag='NNG', start=1123, len=2),
#  Token(form='하', tag='XSV', start=1125, len=1),
#  Token(form='었', tag='EP', start=1125, len=1),
#  Token(form='고', tag='EC', start=1126, len=1),
#  Token(form='막내', tag='NNG', start=1128, len=2),
#  Token(form='투크', tag='NNP', start=1131, len=2),
#  Token(form='도', tag='JX', start=1133, len=1),
#  Token(form='그렇', tag='VA-I', start=1135, len=2),
#  Token(form='었', tag='EP', start=1136, len=1),
#  Token(form='다', tag='EF', start=1137, len=1),
#  Token(form='.', tag='SF', start=1138, len=1),
#  Token(form='그리고', tag='MAJ', start=1140, len=3),
#  Token(form='멧카이', tag='NNG', start=1144, len=3),
#  Token(form='나', tag='JC', start=1147, len=1),
#  Token(form='부족장', tag='NNG', start=1149, len=3),
#  Token(form='의', tag='JKG', start=1152, len=1),
#  Token(form='딸', tag='NNG', start=1154, len=1),
#  Token(form='츠레이야', tag='NNP', start=1156, len=4),
#  Token(form='역시', tag='MAG', start=1161, len=2),
#  Token(form='후반', tag='NNG', start=1164, len=2),
#  Token(form='에', tag='JKB', start=1166, len=1),
#  Token(form='자기', tag='NP', start=1168, len=2),
#  Token(form='엄마', tag='NNG', start=1171, len=2),
#  Token(form='에게', tag='JKB', start=1173, len=2),
#  Token(form='강', tag='XR', start=1176, len=1),
#  Token(form='하', tag='XSA', start=1177, len=1),
#  Token(form='게', tag='EC', start=1178, len=1),
#  Token(form='반발', tag='NNG', start=1180, len=2),
#  Token(form='하', tag='XSV', start=1182, len=1),
#  Token(form='는', tag='ETM', start=1183, len=1),
#  Token(form='등', tag='NNB', start=1185, len=1),
#  Token(form='의', tag='JKG', start=1186, len=1),
#  Token(form='모습', tag='NNG', start=1188, len=2),
#  Token(form='을', tag='JKO', start=1190, len=1),
#  Token(form='보이', tag='VV', start=1192, len=2),
#  Token(form='었', tag='EP', start=1193, len=1),
#  Token(form='다', tag='EF', start=1194, len=1),
#  Token(form='.', tag='SF', start=1195, len=1),
#  Token(form='그렇', tag='VA-I', start=1197, len=2),
#  Token(form='게', tag='EC', start=1199, len=1),
#  Token(form='행동', tag='NNG', start=1201, len=2),
#  Token(form='하', tag='XSV', start=1203, len=1),
#  Token(form='어야', tag='EC', start=1203, len=2),
#  Token(form='만', tag='JX', start=1205, len=1),
#  Token(form='하', tag='VX', start=1207, len=1),
#  Token(form='는', tag='ETM', start=1208, len=1),
#  Token(form='이유', tag='NNG', start=1210, len=2),
#  Token(form='가', tag='JKS', start=1212, len=1),
#  Token(form='있', tag='VV', start=1214, len=1),
#  Token(form='었', tag='EP', start=1215, len=1),
#  Token(form='지만', tag='EC', start=1216, len=2),
#  Token(form=',', tag='SP', start=1218, len=1),
#  Token(form='말', tag='NNG', start=1220, len=1),
#  Token(form='안', tag='MAG', start=1222, len=1),
#  Token(form='듣', tag='VV-I', start=1224, len=1),
#  Token(form='는', tag='ETM', start=1225, len=1),
#  Token(form='애', tag='NNG', start=1227, len=1),
#  Token(form='들', tag='XSN', start=1228, len=1),
#  Token(form='을', tag='JKO', start=1229, len=1),
#  Token(form='워낙', tag='MAG', start=1231, len=2),
#  Token(form='끔찍', tag='XR', start=1234, len=2),
#  Token(form='하', tag='XSA', start=1236, len=1),
#  Token(form='어', tag='EC', start=1236, len=1),
#  Token(form='하', tag='VX', start=1237, len=1),
#  Token(form='는', tag='ETM', start=1238, len=1),
#  Token(form='나', tag='NP', start=1240, len=1),
#  Token(form='로서', tag='JKB', start=1241, len=2),
#  Token(form='는', tag='JX', start=1243, len=1),
#  Token(form='머리', tag='NNG', start=1245, len=2),
#  Token(form='가', tag='JKS', start=1247, len=1),
#  Token(form='아프', tag='VA', start=1249, len=2),
#  Token(form='ᆯ', tag='ETM', start=1250, len=1),
#  Token(form='지경', tag='NNB', start=1252, len=2),
#  Token(form='이', tag='VCP', start=1254, len=1),
#  Token(form='었', tag='EP', start=1255, len=1),
#  Token(form='다', tag='EF', start=1256, len=1),
#  Token(form='.', tag='SF', start=1257, len=1),
#  Token(form='우당탕탕', tag='MAG', start=1259, len=4),
#  Token(form='설리', tag='NNP', start=1264, len=2),
#  Token(form='네', tag='XSN', start=1266, len=1),
#  Token(form='가족', tag='NNG', start=1268, len=2),
#  Token(form='설리', tag='NNP', start=1271, len=2),
#  Token(form='가족', tag='NNG', start=1274, len=2),
#  Token(form='이', tag='JKS', start=1276, len=1),
#  Token(form='바람', tag='NNG', start=1278, len=2),
#  Token(form='상인', tag='NNG', start=1281, len=2),
#  Token(form='과', tag='JKB', start=1283, len=1),
#  Token(form='함께', tag='MAG', start=1285, len=2),
#  Token(form='가', tag='VV', start=1288, len=1),
#  Token(form='던', tag='ETM', start=1289, len=1),
#  Token(form='중', tag='NNB', start=1291, len=1),
#  Token(form='에', tag='JKB', start=1292, len=1),
#  Token(form='망콴', tag='NNP', start=1294, len=2),
#  Token(form='족', tag='NNG', start=1296, len=1),
#  Token(form='이', tag='JKS', start=1297, len=1),
#  Token(form='나타나', tag='VV', start=1299, len=3),
#  Token(form='어', tag='EC', start=1301, len=1),
#  Token(form='공격', tag='NNG', start=1303, len=2),
#  Token(form='을', tag='JKO', start=1305, len=1),
#  Token(form='시작', tag='NNG', start=1307, len=2),
#  Token(form='하', tag='XSV', start=1309, len=1),
#  Token(form='었', tag='EP', start=1309, len=1),
#  Token(form='고', tag='EC', start=1310, len=1),
#  Token(form=',', tag='SP', start=1311, len=1),
#  Token(form='쿼리치', tag='NNP', start=1313, len=3),
#  Token(form='는', tag='JX', start=1316, len=1),
#  Token(form='제이크', tag='NNP', start=1318, len=3),
#  Token(form='를', tag='JKO', start=1321, len=1),
#  Token(form='또', tag='MAG', start=1323, len=1),
#  Token(form='잡', tag='VV-R', start=1325, len=1),
#  Token(form='겠', tag='EP', start=1326, len=1),
#  Token(form='다며', tag='EC', start=1327, len=2),
#  Token(form='나타나', tag='VV', start=1330, len=3),
#  Token(form='었', tag='EP', start=1332, len=1),
#  Token(form='다', tag='EF', start=1333, len=1),
#  Token(form='.', tag='SF', start=1334, len=1),
#  Token(form='그', tag='NP', start=1336, len=1),
#  Token(form='로', tag='JKB', start=1337, len=1),
#  Token(form='인하', tag='VV', start=1339, len=2),
#  Token(form='어', tag='EC', start=1340, len=1),
#  Token(form='한바탕', tag='MAG', start=1342, len=3),
#  Token(form='전쟁', tag='NNG', start=1346, len=2),
#  Token(form='이', tag='JKS', start=1348, len=1),
#  Token(form='벌어지', tag='VV', start=1350, len=3),
#  Token(form='어', tag='EC', start=1352, len=1),
#  Token(form='자랑', tag='NNG', start=1354, len=2),
#  Token(form='이', tag='VCP', start=1356, len=1),
#  Token(form='라도', tag='EC', start=1357, len=2),
#  Token(form='하', tag='VV', start=1360, len=1),
#  Token(form='려는', tag='ETM', start=1361, len=2),
#  Token(form='듯', tag='NNB', start=1364, len=1),
#  Token(form='뛰어나', tag='VA', start=1366, len=3),
#  Token(form='ᆫ', tag='ETM', start=1368, len=1),
#  Token(form='효과', tag='NNG', start=1370, len=2),
#  Token(form='를', tag='JKO', start=1372, len=1),
#  Token(form='보이', tag='VV', start=1374, len=2),
#  Token(form='어', tag='EC', start=1375, len=1),
#  Token(form='주', tag='VX', start=1376, len=1),
#  Token(form='었', tag='EP', start=1376, len=1),
#  Token(form='다', tag='EF', start=1377, len=1),
#  Token(form='.', tag='SF', start=1378, len=1),
#  Token(form='일반', tag='NNG', start=1380, len=2),
#  Token(form='상영관', tag='NNG', start=1383, len=3),
#  Token(form='에서', tag='JKB', start=1386, len=2),
#  Token(form='보', tag='VV', start=1389, len=1),
#  Token(form='었', tag='EP', start=1389, len=1),
#  Token(form='음', tag='ETN', start=1390, len=1),
#  Token(form='에', tag='JKB', start=1391, len=1),
#  Token(form='도', tag='JX', start=1392, len=1),
#  Token(form='가', tag='NNG', start=1394, len=1),
#  Token(form='좋', tag='VA', start=1396, len=1),
#  Token(form='다는', tag='ETM', start=1397, len=2),
#  Token(form='거', tag='NNB', start=1400, len=1),
#  Token(form='ᆫ', tag='JX', start=1400, len=1),
#  Token(form='알', tag='VV', start=1402, len=1),
#  Token(form='ᆯ', tag='ETM', start=1402, len=1),
#  Token(form='수', tag='NNB', start=1404, len=1),
#  Token(form='있', tag='VA', start=1406, len=1),
#  Token(form='었', tag='EP', start=1407, len=1),
#  Token(form='다', tag='EF', start=1408, len=1),
#  Token(form='.', tag='SF', start=1409, len=1),
#  Token(form='하지만', tag='MAJ', start=1411, len=3),
#  Token(form='한', tag='MM', start=1415, len=1),
#  Token(form='가지', tag='NNB', start=1417, len=2),
#  Token(form='의아', tag='NNG', start=1420, len=2),
#  Token(form='하', tag='XSA', start=1422, len=1),
#  Token(form='었', tag='EP', start=1422, len=1),
#  Token(form='던', tag='ETM', start=1423, len=1),
#  Token(form='거', tag='NNB', start=1425, len=1),
#  Token(form='ᆫ', tag='JX', start=1425, len=1),
#  Token(form='가', tag='VV', start=1427, len=1),
#  Token(form='버벅', tag='NNG', start=1429, len=2),
#  Token(form='거리', tag='XSV', start=1431, len=2),
#  Token(form='ᆫ다는', tag='ETM', start=1432, len=3),
#  Token(form='느낌', tag='NNG', start=1436, len=2),
#  Token(form='이', tag='JKS', start=1438, len=1),
#  Token(form='들', tag='VX', start=1440, len=1),
#  Token(form='는', tag='ETM', start=1441, len=1),
#  Token(form='장면', tag='NNG', start=1443, len=2),
#  Token(form='이', tag='JKS', start=1445, len=1),
#  Token(form='종종', tag='MAG', start=1447, len=2),
#  Token(form='있', tag='VV', start=1450, len=1),
#  Token(form='었', tag='EP', start=1451, len=1),
#  Token(form='다는', tag='ETM', start=1452, len=2),
#  Token(form='것', tag='NNB', start=1455, len=1),
#  Token(form='이', tag='VCP', start=1456, len=1),
#  Token(form='다', tag='EF', start=1457, len=1),
#  Token(form='.', tag='SF', start=1458, len=1),
#  Token(form='망콴', tag='NNP', start=1460, len=2),
#  Token(form='족', tag='NNG', start=1462, len=1),
#  Token(form='때문', tag='NNB', start=1464, len=2),
#  Token(form='에', tag='JKB', start=1466, len=1),
#  Token(form='말', tag='NNG', start=1468, len=1),
#  Token(form='안', tag='MAG', start=1470, len=1),
#  Token(form='듣', tag='VV-I', start=1472, len=1),
#  Token(form='는', tag='ETM', start=1473, len=1),
#  Token(form='아이', tag='NNG', start=1475, len=2),
#  Token(form='들', tag='XSN', start=1477, len=1),
#  Token(form='은', tag='JX', start=1478, len=1),
#  Token(form='자기', tag='NP', start=1480, len=2),
#  Token(form='들', tag='XSN', start=1482, len=1),
#  Token(form='끼리', tag='XSN', start=1483, len=2),
#  Token(form='도망', tag='NNG', start=1486, len=2),
#  Token(form='을', tag='JKO', start=1488, len=1),
#  Token(form='치', tag='VV', start=1490, len=1),
#  Token(form='어야', tag='EC', start=1490, len=2),
#  Token(form='하', tag='VX', start=1493, len=1),
#  Token(form='었', tag='EP', start=1493, len=1),
#  Token(form='고', tag='EC', start=1494, len=1),
#  Token(form='네', tag='IC', start=1496, len=1),
#  Token(form='이', tag='MM', start=1497, len=1),
#  Token(form='티', tag='NNG', start=1498, len=1),
#  Token(form='리', tag='NNG', start=1499, len=1),
#  Token(form='는', tag='JX', start=1500, len=1),
#  Token(form='망콴', tag='NNP', start=1502, len=2),
#  Token(form='족', tag='NNG', start=1504, len=1),
#  Token(form='의', tag='JKG', start=1505, len=1),
#  Token(form='부족장', tag='NNG', start=1507, len=3),
#  Token(form='바랑', tag='NNG', start=1511, len=2),
#  Token(form='이', tag='JKS', start=1513, len=1),
#  Token(form='쏘', tag='VV', start=1515, len=1),
#  Token(form='ᆫ', tag='ETM', start=1515, len=1),
#  Token(form='활', tag='NNG', start=1517, len=1),
#  Token(form='에', tag='JKB', start=1518, len=1),
#  Token(form='크', tag='VA', start=1520, len=1),
#  Token(form='게', tag='EC', start=1521, len=1),
#  Token(form='다치', tag='VV', start=1523, len=2),
#  Token(form='고', tag='EC', start=1525, len=1),
#  Token(form='말', tag='VX', start=1527, len=1),
#  Token(form='었', tag='EP', start=1528, len=1),
#  Token(form='다', tag='EF', start=1529, len=1),
#  Token(form='.', tag='SF', start=1530, len=1),
#  Token(form='그리고', tag='MAJ', start=1532, len=3),
#  Token(form='제이크', tag='NNP', start=1536, len=3),
#  Token(form='는', tag='JX', start=1539, len=1),
#  Token(form='쿼리치', tag='NNP', start=1541, len=3),
#  Token(form='에게', tag='JKB', start=1544, len=2),
#  Token(form='붙잡히', tag='VV', start=1547, len=3),
#  Token(form='고', tag='EC', start=1550, len=1),
#  Token(form='말', tag='VX', start=1552, len=1),
#  Token(form='었', tag='EP', start=1553, len=1),
#  Token(form='다', tag='EF', start=1554, len=1),
#  Token(form='.', tag='SF', start=1555, len=1),
#  Token(form='제이크', tag='NNP', start=1557, len=3),
#  Token(form='는', tag='JX', start=1560, len=1),
#  Token(form='아이', tag='NNG', start=1562, len=2),
#  Token(form='들', tag='XSN', start=1564, len=1),
#  Token(form='이', tag='JKS', start=1565, len=1),
#  Token(form='무전기', tag='NNG', start=1567, len=3),
#  Token(form='도', tag='JX', start=1570, len=1),
#  Token(form='차', tag='VV', start=1572, len=1),
#  Token(form='지', tag='EC', start=1573, len=1),
#  Token(form='않', tag='VX', start=1575, len=1),
#  Token(form='었', tag='EP', start=1576, len=1),
#  Token(form='고', tag='EC', start=1577, len=1),
#  Token(form='스파이더', tag='NNP', start=1579, len=4),
#  Token(form='의', tag='JKG', start=1583, len=1),
#  Token(form='마스크', tag='NNG', start=1585, len=3),
#  Token(form='도', tag='JX', start=1588, len=1),
#  Token(form='버리', tag='VV', start=1590, len=2),
#  Token(form='어', tag='EC', start=1591, len=1),
#  Token(form='지', tag='VX', start=1592, len=1),
#  Token(form='어', tag='EC', start=1592, len=1),
#  Token(form='있', tag='VX', start=1594, len=1),
#  Token(form='는', tag='ETM', start=1595, len=1),
#  Token(form='거', tag='NNB', start=1597, len=1),
#  Token(form='ᆯ', tag='JKO', start=1597, len=1),
#  Token(form='보', tag='VV', start=1599, len=1),
#  Token(form='고', tag='EC', start=1600, len=1),
#  Token(form='는', tag='JX', start=1601, len=1),
#  Token(form='쿼리치', tag='NNP', start=1603, len=3),
#  Token(form='에게', tag='JKB', start=1606, len=2),
#  Token(form='아이', tag='NNG', start=1609, len=2),
#  Token(form='들', tag='XSN', start=1611, len=1),
#  Token(form='을', tag='JKO', start=1612, len=1),
#  Token(form='먼저', tag='MAG', start=1614, len=2),
#  Token(form='구하', tag='VV', start=1617, len=2),
#  Token(form='어야', tag='EC', start=1618, len=2),
#  Token(form='하', tag='VX', start=1621, len=1),
#  Token(form='ᆫ다고', tag='EC', start=1621, len=3),
#  Token(form='말', tag='NNG', start=1625, len=1),
#  Token(form='하', tag='XSV', start=1626, len=1),
#  Token(form='었', tag='EP', start=1626, len=1),
#  Token(form='다', tag='EF', start=1627, len=1),
#  Token(form='.', tag='SF', start=1628, len=1),
#  Token(form='쿼리', tag='NNP', start=1630, len=2),
#  Token(form='치', tag='XSN', start=1632, len=1),
#  Token(form='는', tag='JX', start=1633, len=1),
#  Token(form='저', tag='NP', start=1635, len=1),
#  Token(form='의', tag='JKG', start=1635, len=1),
#  Token(form='아들', tag='NNG', start=1637, len=2),
#  Token(form='에게', tag='JKB', start=1639, len=2),
#  Token(form='의외로', tag='MAG', start=1642, len=3),
#  Token(form='약하', tag='VA', start=1646, len=2),
#  Token(form='었', tag='EP', start=1647, len=1),
#  Token(form='던', tag='ETM', start=1648, len=1),
#  Token(form='터', tag='NNB', start=1650, len=1),
#  Token(form='이', tag='VCP', start=1651, len=0),
#  Token(form='라', tag='EC', start=1651, len=1),
#  Token(form='얼마', tag='NNG', start=1653, len=2),
#  Token(form='동안', tag='NNG', start=1656, len=2),
#  Token(form='손', tag='NNG', start=1659, len=1),
#  Token(form='을', tag='JKO', start=1660, len=1),
#  Token(form='잡', tag='VV-R', start=1662, len=1),
#  Token(form='고', tag='EC', start=1663, len=1),
#  Token(form='아이', tag='NNG', start=1665, len=2),
#  Token(form='들', tag='XSN', start=1667, len=1),
#  Token(form='의', tag='JKG', start=1668, len=1),
#  Token(form='행적', tag='NNG', start=1670, len=2),
#  Token(form='을', tag='JKO', start=1672, len=1),
#  Token(form='쫓', tag='VV', start=1674, len=1),
#  Token(form='기', tag='ETN', start=1675, len=1),
#  Token(form='시작', tag='NNG', start=1677, len=2),
#  Token(form='하', tag='XSV', start=1679, len=1),
#  Token(form='었', tag='EP', start=1679, len=1),
#  Token(form='다', tag='EF', start=1680, len=1),
#  Token(form='.', tag='SF', start=1681, len=1),
#  Token(form='하지만', tag='MAJ', start=1682, len=3),
#  Token(form='목표', tag='NNG', start=1686, len=2),
#  Token(form='를', tag='JKO', start=1688, len=1),
#  Token(form='달성', tag='NNG', start=1690, len=2),
#  Token(form='하', tag='XSV', start=1692, len=1),
#  Token(form='ᆫ', tag='ETM', start=1692, len=1),
#  Token(form='후', tag='NNG', start=1694, len=1),
#  Token(form='에', tag='JKB', start=1695, len=1),
#  Token(form='제이크', tag='NNP', start=1697, len=3),
#  Token(form='와', tag='JC', start=1700, len=1),
#  Token(form='쿼리치', tag='NNP', start=1702, len=3),
#  Token(form='는', tag='JX', start=1705, len=1),
#  Token(form='다시', tag='MAG', start=1707, len=2),
#  Token(form='적', tag='NNB', start=1710, len=1),
#  Token(form='으로', tag='JKB', start=1711, len=2),
#  Token(form='돌아가', tag='VV', start=1714, len=3),
#  Token(form='ᆯ', tag='ETM', start=1716, len=1),
#  Token(form='수', tag='NNB', start=1718, len=1),
#  Token(form='밖에', tag='JX', start=1719, len=2),
#  Token(form='없', tag='VA', start=1722, len=1),
#  Token(form='었', tag='EP', start=1723, len=1),
#  Token(form='다', tag='EF', start=1724, len=1),
#  Token(form='.', tag='SF', start=1725, len=1),
#  Token(form='그', tag='NP', start=1727, len=1),
#  Token(form='로', tag='JKB', start=1728, len=1),
#  Token(form='인하', tag='VV', start=1730, len=2),
#  Token(form='어', tag='EC', start=1731, len=1),
#  Token(form='적', tag='NNG', start=1733, len=1),
#  Token(form='의', tag='JKG', start=1734, len=1),
#  Token(form='적', tag='NNG', start=1736, len=1),
#  Token(form='이', tag='VCP', start=1737, len=1),
#  Token(form='ᆫ', tag='ETM', start=1737, len=1),
#  Token(form='망콴', tag='NNP', start=1739, len=2),
#  Token(form='의', tag='JKG', start=1741, len=1),
#  Token(form='바랑', tag='NNG', start=1743, len=2),
#  Token(form='과', tag='JC', start=1745, len=1),
#  Token(form='쿼리치', tag='NNP', start=1747, len=3),
#  Token(form='가', tag='JKS', start=1750, len=1),
#  Token(form='손', tag='NNG', start=1752, len=1),
#  Token(form='을', tag='JKO', start=1753, len=1),
#  Token(form='잡', tag='VV-R', start=1755, len=1),
#  Token(form='게', tag='EC', start=1756, len=1),
#  Token(form='되', tag='VV', start=1758, len=1),
#  Token(form='ᆫ', tag='ETM', start=1758, len=1),
#  Token(form='거', tag='NNB', start=1760, len=1),
#  Token(form='ᆫ', tag='JX', start=1760, len=1),
#  Token(form='당연', tag='XR', start=1762, len=2),
#  Token(form='하', tag='XSA', start=1764, len=1),
#  Token(form='었', tag='EP', start=1764, len=1),
#  Token(form='다', tag='EF', start=1765, len=1),
#  Token(form='.', tag='SF', start=1766, len=1),
#  Token(form='범죄도시', tag='NNP', start=1768, len=4),
#  Token(form='시리즈', tag='NNG', start=1773, len=3),
#  Token(form='를', tag='JKO', start=1776, len=1),
#  Token(form='보', tag='VV', start=1778, len=1),
#  Token(form='는', tag='ETM', start=1779, len=1),
#  Token(form='듯', tag='NNB', start=1781, len=1),
#  Token(form='하', tag='XSA', start=1782, len=1),
#  Token(form='ᆫ', tag='ETM', start=1782, len=1),
#  Token(form='감흥', tag='NNG', start=1784, len=2),
#  Token(form='사실', tag='MAG', start=1787, len=2),
#  Token(form='나', tag='NP', start=1790, len=1),
#  Token(form='는', tag='JX', start=1791, len=1),
#  Token(form='2', tag='SN', start=1793, len=1),
#  Token(form='편', tag='NNB', start=1794, len=1),
#  Token(form='도', tag='JX', start=1795, len=1),
#  Token(form='재미있', tag='VA', start=1797, len=3),
#  Token(form='게', tag='EC', start=1800, len=1),
#  Token(form='보', tag='VV', start=1802, len=1),
#  Token(form='지', tag='EC', start=1803, len=1),
#  Token(form='ᆯ', tag='JKO', start=1803, len=1),
#  Token(form='않', tag='VX', start=1805, len=1),
#  Token(form='었', tag='EP', start=1806, len=1),
#  Token(form='다', tag='EF', start=1807, len=1),
#  Token(form='.', tag='SF', start=1808, len=1),
#  Token(form='3', tag='SN', start=1810, len=1),
#  Token(form='아이맥스', tag='NNP', start=1812, len=4),
#  Token(form='로', tag='JKB', start=1816, len=1),
#  Token(form='보', tag='VV', start=1818, len=1),
#  Token(form='었', tag='EP', start=1818, len=1),
#  Token(form='고', tag='EC', start=1819, len=1),
#  Token(form='기술력', tag='NNG', start=1821, len=3),
#  Token(form='에', tag='JKB', start=1824, len=1),
#  Token(form='감탄', tag='NNG', start=1826, len=2),
#  Token(form='하', tag='XSV', start=1828, len=1),
#  Token(form='기', tag='ETN', start=1829, len=1),
#  Token(form='ᆫ', tag='JX', start=1829, len=1),
#  Token(form='하', tag='VX', start=1831, len=1),
#  Token(form='었', tag='EP', start=1831, len=1),
#  Token(form='지만', tag='EC', start=1832, len=2),
#  Token(form='그것', tag='NP', start=1835, len=2),
#  Token(form='이', tag='JKS', start=1836, len=1),
#  Token(form='끝', tag='NNG', start=1838, len=1),
#  Token(form='이', tag='VCP', start=1839, len=1),
#  Token(form='었', tag='EP', start=1840, len=1),
#  Token(form='다', tag='EF', start=1841, len=1),
#  Token(form='.', tag='SF', start=1842, len=1),
#  Token(form='영화', tag='NNG', start=1844, len=2),
#  Token(form='를', tag='JKO', start=1846, len=1),
#  Token(form='영상미', tag='NNG', start=1848, len=3),
#  Token(form='나', tag='JC', start=1851, len=1),
#  Token(form='로', tag='NNP', start=1853, len=1),
#  Token(form='만', tag='JX', start=1854, len=1),
#  Token(form='보', tag='VV', start=1856, len=1),
#  Token(form='는', tag='ETM', start=1857, len=1),
#  Token(form='것', tag='NNB', start=1859, len=1),
#  Token(form='이', tag='JKC', start=1859, len=1),
#  Token(form='아니', tag='VCN', start=1861, len=2),
#  ...]

# %%
# 일반명사만 추출(NNG)
# token 의 리스트를 돌면서, tag 가 NNG인 form을 nng_list 에 담아주세요~
nng_list = []
for t in token:
    if t.tag == 'NNG':
        nng_list.append(t.form)

# %%
nng_list
# Out:
# ['영화',
#  '정보',
#  '줄거리',
#  '리뷰',
#  '영화',
#  '정보',
#  '기본',
#  '정보',
#  '원',
#  '수입',
#  '배급',
#  '컴퍼니',
#  '감독',
#  '출연',
#  '제작',
#  '국가',
#  '장르',
#  '액션',
#  '모험',
#  '판타지',
#  '스릴러',
#  '관람',
#  '등급',
#  '이상',
#  '관람',
#  '가',
#  '상영',
#  '시간',
#  '극장',
#  '개봉',
#  '줄거리',
#  '아들',
#  '가족',
#  '애도',
#  '가족',
#  '위기',
#  '리뷰',
#  '관람',
#  '포인트',
#  '말',
#  '아이',
#  '복습',
#  '시작',
#  '영화',
#  '오프닝',
#  '전편',
#  '사망',
#  '등장',
#  '자유',
#  '비행',
#  '모습',
#  '나비',
#  '족',
#  '의식',
#  '형',
#  '대화',
#  '시간',
#  '자신',
#  '방식',
#  '형',
#  '때',
#  '엄마',
#  '상실감',
#  '아무것',
#  '인간',
#  '공격',
#  '예상',
#  '바다',
#  '인간',
#  '전함',
#  '총',
#  '각종',
#  '무기',
#  '시작',
#  '가족',
#  '의지',
#  '부족장',
#  '반발',
#  '뜻',
#  '인간',
#  '바람',
#  '상인',
#  '편',
#  '아들',
#  '공격',
#  '스파이더',
#  '반발',
#  '아이',
#  '가족',
#  '부모',
#  '뜻',
#  '의견',
#  '분위기',
#  '바람',
#  '상인',
#  '가족',
#  '시작',
#  '불안',
#  '불안',
#  '사건',
#  '이전',
#  '마스크',
#  '문제',
#  '무전기',
#  '아이',
#  '말',
#  '전편',
#  '말',
#  '아이',
#  '짜증',
#  '기억',
#  '이번',
#  '어처구니',
#  '정신',
#  '이후',
#  '영화',
#  '후반',
#  '키리',
#  '형제',
#  '자신',
#  '뜻',
#  '행동',
#  '막내',
#  '멧카이',
#  '부족장',
#  '딸',
#  '후반',
#  '엄마',
#  '반발',
#  '모습',
#  '행동',
#  '이유',
#  '말',
#  '애',
#  '머리',
#  '가족',
#  '가족',
#  '바람',
#  '상인',
#  '족',
#  '공격',
#  '시작',
#  '전쟁',
#  '자랑',
#  '효과',
#  '일반',
#  '상영관',
#  '가',
#  '의아',
#  '버벅',
#  '느낌',
#  '장면',
#  '족',
#  '말',
#  '아이',
#  '도망',
#  '티',
#  '리',
#  '족',
#  '부족장',
#  '바랑',
#  '활',
#  '아이',
#  '무전기',
#  '마스크',
#  '아이',
#  '말',
#  '아들',
#  '얼마',
#  '동안',
#  '손',
#  '아이',
#  '행적',
#  '시작',
#  '목표',
#  '달성',
#  '후',
#  '적',
#  '적',
#  '바랑',
#  '손',
#  '시리즈',
#  '감흥',
#  '기술력',
#  '감탄',
#  '끝',
#  '영화',
#  '영상미',
#  '사람',
#  '내용',
#  '러닝',
#  '타임',
#  '의문',
#  '영화',
#  '전개',
#  '말',
#  '아이',
#  '사건',
#  '사고',
#  '연속',
#  '점',
#  '마음',
#  '특별',
#  '관',
#  '생각',
#  '일반',
#  '상영관',
#  '버벅',
#  '때',
#  '일반',
#  '상영관',
#  '스크린',
#  '기술력',
#  '인정',
#  '이야기',
#  '회의',
#  '가족',
#  '아이',
#  '말',
#  '전생',
#  '원수',
#  '포기',
#  '자연',
#  '공생',
#  '나비',
#  '족',
#  '선',
#  '생명체',
#  '자연',
#  '파괴',
#  '인간',
#  '의미',
#  '전편',
#  '도움',
#  '인간',
#  '가족',
#  '공격',
#  '족',
#  '악당',
#  '변화',
#  '전체',
#  '인상',
#  '영화',
#  '차이',
#  '장면',
#  '지금',
#  '영화',
#  '일',
#  '피로감',
#  '영화',
#  '시리즈',
#  '시리즈',
#  '차이',
#  '주먹',
#  '승부',
#  '형사',
#  '도',
#  '범죄자',
#  '소탕',
#  '시각',
#  '즐거움',
#  '현실',
#  '존재',
#  '세계',
#  '말',
#  '차이',
#  '시리즈',
#  '전체',
#  '패턴',
#  '흥미',
#  '이번',
#  '영화',
#  '사건',
#  '해결',
#  '중심',
#  '키리',
#  '일',
#  '마지막',
#  '전투',
#  '해결',
#  '세계관',
#  '신',
#  '키리',
#  '생각',
#  '대부분',
#  '사람',
#  '최고',
#  '기대작',
#  '기대',
#  '불',
#  '재',
#  '기대',
#  '인상',
#  '캐릭터',
#  '사건',
#  '사고',
#  '연속',
#  '결말',
#  '선',
#  '흐름',
#  '로',
#  '영화',
#  '시각',
#  '효과',
#  '내용',
#  '영화',
#  '오락',
#  '영화',
#  '사람',
#  '극장',
#  '덧',
#  '영화',
#  '상영',
#  '전',
#  '예고편',
#  '때',
#  '심장',
#  '불',
#  '재',
#  '액션',
#  '모험',
#  '영화',
#  '불',
#  '재',
#  '로',
#  '관람',
#  '물',
#  '길',
#  '개봉',
#  '개봉',
#  '시리즈',
#  '이번',
#  '관객',
#  '동원',
#  '가능',
#  '귀추',
#  '주목',
#  '현재',
#  '국내',
#  '초반',
#  '흥행',
#  '추이',
#  '장기',
#  '흥행',
#  '평가',
#  '이전',
#  '시네마',
#  '월드',
#  '관람',
#  '은',
#  '재의',
#  '부족',
#  '등장',
#  '분노',
#  '불',
#  '슬픔',
#  '재',
#  '바탕',
#  '폭력',
#  '부족',
#  '물',
#  '길',
#  '물',
#  '소재',
#  '강조',
#  '불',
#  '재',
#  '불',
#  '소재',
#  '이미지',
#  '강조',
#  '작품',
#  '러닝',
#  '타임',
#  '시간',
#  '감독',
#  '영화',
#  '재미',
#  '화장실',
#  '동안',
#  '아쉬움',
#  '기술력',
#  '발전',
#  '이야기',
#  '반복',
#  '이유',
#  '반복',
#  '이야기',
#  '구조',
#  '부족',
#  '등장',
#  '이야기',
#  '전개',
#  '판박이',
#  '전개',
#  '느낌',
#  '동시',
#  '촬영',
#  '정도',
#  '가족',
#  '스파이더',
#  '부족',
#  '공격',
#  '대립',
#  '패턴',
#  '반복',
#  '장면',
#  '장면',
#  '편',
#  '기시감',
#  '변주',
#  '캐릭터',
#  '적극',
#  '활용',
#  '중요',
#  '요소',
#  '급부상',
#  '변수',
#  '작용',
#  '변화',
#  '점',
#  '아들',
#  '가족',
#  '변화',
#  '중요',
#  '존재',
#  '부각',
#  '점',
#  '점',
#  '족',
#  '런',
#  '재의',
#  '부족',
#  '바',
#  '캐릭터',
#  '생각',
#  '점',
#  '마녀',
#  '악녀',
#  '주술사',
#  '이미지',
#  '폭력',
#  '액션',
#  '이미지',
#  '점',
#  '만족',
#  '이번',
#  '런',
#  '배',
#  '느낌',
#  '배우',
#  '연기',
#  '요염',
#  '팜므',
#  '파탈',
#  '캐릭터',
#  '표현',
#  '불',
#  '재',
#  '이미지',
#  '신',
#  '캐릭터',
#  '관람',
#  '포맷',
#  '울트라',
#  '월드',
#  '관',
#  '평일',
#  '가격',
#  '효과',
#  '효과',
#  '만족',
#  '안경',
#  '사이',
#  '안경',
#  '눈',
#  '부담',
#  '이전',
#  '동안',
#  '안경',
#  '시작',
#  '손',
#  '물',
#  '효과',
#  '불',
#  '이미지',
#  '공중',
#  '입체',
#  '액션',
#  '씬',
#  '효과',
#  '포맷',
#  '일반',
#  '관',
#  '포맷',
#  '차',
#  '관람',
#  '입체',
#  '효과',
#  '효과',
#  '포맷',
#  '시',
#  '바람',
#  '불빛',
#  '물',
#  '정도',
#  '대신',
#  '이번',
#  '공중',
#  '액션',
#  '씬',
#  '부분',
#  '효과',
#  '추천',
#  '표',
#  '관람',
#  '시리즈',
#  '시네마',
#  '체험',
#  '영화',
#  '오프닝',
#  '물',
#  '길',
#  '장면',
#  '시작',
#  '불',
#  '재',
#  '타이틀',
#  '작품',
#  '이미지',
#  '선사',
#  '정도',
#  '사이',
#  '기술력',
#  '발전',
#  '기술력',
#  '영화',
#  '물',
#  '길',
#  '작품',
#  '물',
#  '영상',
#  '인상',
#  '볼거리',
#  '씬',
#  '후반부',
#  '자기장',
#  '전투',
#  '씬',
#  '공중',
#  '액션',
#  '씬',
#  '부분',
#  '해양',
#  '액션',
#  '씬',
#  '이미지',
#  '공중',
#  '장면',
#  '전체',
#  '연장선',
#  '이야기',
#  '볼거리',
#  '느낌',
#  '영상',
#  '혁명',
#  '속편',
#  '비',
#  '기술력',
#  '내용',
#  '단독',
#  '느낌',
#  '느낌',
#  '느낌',
#  '연장선',
#  '느낌',
#  '내용',
#  '시간',
#  '얘기',
#  '이번',
#  '갈등',
#  '파괴',
#  '후',
#  '수용',
#  '메시지',
#  '이야기',
#  '반복',
#  '느낌',
#  '영화',
#  '비주얼',
#  '작품',
#  '극장',
#  '영화',
#  '소리',
#  '영화',
#  '때',
#  '동안',
#  '영화',
#  '작품',
#  '특징',
#  '시리즈',
#  '재미',
#  '때',
#  '경험',
#  '얘기',
#  '시리즈',
#  '이야기',
#  '기술력',
#  '영상',
#  '느낌',
#  '재미',
#  '토루크',
#  '토',
#  '가족',
#  '이야기',
#  '특별',
#  '관',
#  '포맷',
#  '극장',
#  '영화',
#  '후기',
#  '리뷰',
#  '불',
#  '재',
#  '액션',
#  '모험',
#  '이번',
#  '기대',
#  '이상',
#  '시각',
#  '효과',
#  '역대',
#  '급',
#  '스케일',
#  '전쟁',
#  '전투',
#  '장면',
#  '전편',
#  '갈등',
#  '요소',
#  '재탕',
#  '불',
#  '재',
#  '액션',
#  '모험',
#  '영화',
#  '정보',
#  '불',
#  '재',
#  '모험',
#  '영화',
#  '감독',
#  '이상',
#  '관람',
#  '가',
#  '키',
#  '워드',
#  '액션',
#  '시리즈',
#  '외계',
#  '행성',
#  '줄거리',
#  '위협',
#  '재의',
#  '부족',
#  '이상',
#  '인간',
#  '적',
#  '모두',
#  '운명',
#  '거대',
#  '전투',
#  '시작',
#  '인간',
#  '전쟁',
#  '아들',
#  '을',
#  '후',
#  '슬픔',
#  '상실',
#  '앞',
#  '바랑',
#  '재의',
#  '부족',
#  '등장',
#  '위험',
#  '가족',
#  '선택',
#  '기로',
#  '영화',
#  '영화',
#  '추천',
#  '영화',
#  '이야기',
#  '처음',
#  '개봉',
#  '당시',
#  '세계',
#  '사람',
#  '영화',
#  '일례',
#  '감독',
#  '배경',
#  '행성',
#  '촬영',
#  '우스갯소리',
#  '정도',
#  '실제',
#  '분간',
#  '사실감',
#  '시각',
#  '효과',
#  '영화',
#  '이번',
#  '개봉',
#  '눈',
#  '영화',
#  '후기',
#  '극장',
#  '필요',
#  '증명',
#  '대형',
#  '스크린',
#  '때',
#  '영화',
#  '성공',
#  '후',
#  '이야기',
#  '감사',
#  '이번',
#  '이전',
#  '시리즈',
#  '마찬가지',
#  '눈',
#  '호강',
#  '장면',
#  '퀄리티',
#  '현실감',
#  '숨',
#  '인물',
#  '생동감',
#  '남녀노소',
#  '단순',
#  '이야기',
#  '가족',
#  '애',
#  '중심',
#  '소재',
#  '연말',
#  '개봉',
#  '가족',
#  '단위',
#  '영화',
#  '생각',
#  '역대',
#  '시리즈',
#  '로',
#  '관람',
#  '때',
#  '만족',
#  '안경',
#  '러닝',
#  '타임',
#  '압박',
#  '부담',
#  '스크린',
#  '영화관',
#  '생각',
#  '이야기',
#  '전편',
#  '점',
#  '러닝',
#  '타임',
#  '부담',
#  '참고',
#  '흥미',
#  '이야기',
#  '가족',
#  '오락',
#  '영화',
#  '정석',
#  '체감',
#  '러닝',
#  '타임',
#  '느낌',
#  '고려',
#  '점',
#  '촬영',
#  '물',
#  '길',
#  '연장선',
#  '느낌',
#  '이야기',
#  '시리즈',
#  '느낌',
#  '영화',
#  '주제',
#  '의식',
#  '개봉',
#  '이후',
#  '비주얼',
#  '연속',
#  '비교',
#  '아쉬움',
#  '재의',
#  '부족',
#  '망콴',
#  '바',
#  '부족',
#  '등장',
#  '바랑',
#  '존재감',
#  '불',
#  '재난',
#  '재앙',
#  '방관',
#  '분노',
#  '풍요',
#  '삶',
#  '느낌',
#  '매력',
#  '자연',
#  '친화',
#  '우호',
#  '나비',
#  '족',
#  '결',
#  '대비',
#  '캐릭터',
#  '이제',
#  '인류',
#  '대립',
#  '변수',
#  '화제',
#  '점',
#  '유의미',
#  '독보',
#  '캐릭터',
#  '행보',
#  '광기',
#  '이후',
#  '시리즈',
#  '내막',
#  '바람',
#  '나비',
#  '족',
#  '등장',
#  '재미',
#  '바람',
#  '이동',
#  '나비',
#  '족',
#  '상인',
#  '공기',
#  '주머니',
#  '하늘',
#  '생명체',
#  '활용',
#  '부유',
#  '각지',
#  '나비',
#  '족',
#  '물자',
#  '제공',
#  '거래',
#  '규모',
#  '거대',
#  '부족',
#  '유사',
#  '숲',
#  '물',
#  '나비',
#  '족',
#  '자신',
#  '방식',
#  '자연',
#  '속',
#  '모습',
#  '점',
#  '각각',
#  '삶',
#  '방식',
#  '재의',
#  '부족',
#  '공격',
#  '퇴장',
#  '해양',
#  '전쟁',
#  '신',
#  '이야기',
#  '전작',
#  '바다',
#  '전투',
#  '숲',
#  '느낌',
#  '선사',
#  '이번',
#  '해양',
#  '전쟁',
#  '거대',
#  '규모',
#  '전쟁',
#  '인류',
#  '나비',
#  '족',
#  '사활',
#  '대결',
#  '장엄',
#  '거대',
#  '규모',
#  '재미',
#  '영화',
#  '이야기',
#  '단순',
#  '액션',
#  '신',
#  '생각',
#  '퀄리티',
#  '시퀀스',
#  '영화',
#  '가치',
#  '해양',
#  '생명체',
#  '인류',
#  '진격',
#  '때',
#  '몸',
#  '전율',
#  '유사',
#  '캐릭터',
#  '성장',
#  '서사',
#  '점',
#  '캐릭터',
#  '갈등',
#  '구조',
#  '위기',
#  '상황',
#  '유사',
#  '연장선',
#  '느낌',
#  '단순',
#  '납치',
#  '구조',
#  '탈출',
#  '위기',
#  '남발',
#  '긴장감',
#  '반감',
#  '정도',
#  '역효과',
#  '러닝',
#  '타임',
#  '갈등',
#  '구조',
#  '해소',
#  '방식',
#  '전',
#  '동일',
#  '유야무야',
#  '스토리텔링',
#  '구조',
#  '후반부',
#  '정도',
#  '반복',
#  '피로감',
#  '생각',
#  '개인',
#  '외부',
#  '갈등',
#  '폭력',
#  '내부',
#  '해결',
#  '가족',
#  '서사',
#  '드라마',
#  '주인공',
#  '서사',
#  '이번',
#  '이야기',
#  '주인공',
#  '하늘',
#  '인간',
#  '외부인',
#  '나비',
#  '족',
#  '인정',
#  '동화',
#  '이야기',
#  '연인',
#  '가족',
#  '이야기',
#  '식구',
#  '포지션',
#  '스파이더',
#  '이야기',
#  '주',
#  '나비',
#  '족',
#  '성장',
#  ...]

# %%
# 간편하게 리스트에 데이터를 누적하는 방법
# 리스트명 = [실행문 반복문 조건]
nng_list = [t.form for t in token in if t.tag=='NNG']

# %%
# List 에 담긴 데이터의 개수를 세서 많이 나오는 단어로 워드클라우드 생성
counter = Counter(nng_list)
counter
# Out:
# Counter({'영화': 120,
#          '족': 61,
#          '부족': 55,
#          '불': 51,
#          '재': 49,
#          '가족': 44,
#          '이번': 43,
#          '시리즈': 43,
#          '작품': 43,
#          '나비': 37,
#          '개봉': 33,
#          '이야기': 32,
#          '액션': 31,
#          '인간': 31,
#          '관람': 30,
#          '물': 28,
#          '장면': 26,
#          '바랑': 26,
#          '등장': 25,
#          '타임': 25,
#          '러닝': 24,
#          '시간': 23,
#          '점': 23,
#          '시작': 21,
#          '전투': 21,
#          '극장': 20,
#          '길': 20,
#          '모습': 19,
#          '이후': 19,
#          '키리': 19,
#          '느낌': 19,
#          '감독': 18,
#          '생각': 18,
#          '관객': 17,
#          '정도': 17,
#          '아이': 16,
#          '자신': 16,
#          '행성': 15,
#          '줄거리': 14,
#          '모험': 14,
#          '말': 14,
#          '때': 14,
#          '내용': 14,
#          '결말': 14,
#          '반복': 14,
#          '전작': 14,
#          '리뷰': 13,
#          '전쟁': 13,
#          '캐릭터': 13,
#          '재의': 13,
#          '상영': 12,
#          '효과': 12,
#          '세계': 12,
#          '재미': 12,
#          '부분': 12,
#          '정보': 11,
#          '아들': 11,
#          '위기': 11,
#          '전편': 11,
#          '공격': 11,
#          '거대': 11,
#          '서사': 11,
#          '예정': 11,
#          '이상': 10,
#          '존재': 10,
#          '이미지': 10,
#          '배우': 10,
#          '추천': 10,
#          '영상': 10,
#          '가': 9,
#          '바람': 9,
#          '사건': 9,
#          '신': 9,
#          '기대': 9,
#          '전': 9,
#          '국내': 9,
#          '만족': 9,
#          '씬': 9,
#          '후기': 9,
#          '성공': 9,
#          '주인공': 9,
#          '스토리': 9,
#          '신작': 9,
#          '교감': 9,
#          '제작': 8,
#          '바다': 8,
#          '동안': 8,
#          '후': 8,
#          '자연': 8,
#          '흥행': 8,
#          '촬영': 8,
#          '런': 8,
#          '해양': 8,
#          '갈등': 8,
#          '배경': 8,
#          '생물': 8,
#          '등급': 7,
#          '총': 7,
#          '상인': 7,
#          '스파이더': 7,
#          '마스크': 7,
#          '이유': 7,
#          '기술력': 7,
#          '사람': 7,
#          '전개': 7,
#          '마음': 7,
#          '예고편': 7,
#          '평가': 7,
#          '사이': 7,
#          '토': 7,
#          '모두': 7,
#          '처음': 7,
#          '인류': 7,
#          '속': 7,
#          '대결': 7,
#          '몸': 7,
#          '감상': 7,
#          '연출': 7,
#          '비행선': 7,
#          '대령': 7,
#          '이벤트': 7,
#          '부모': 6,
#          '끝': 6,
#          '연속': 6,
#          '주목': 6,
#          '아쉬움': 6,
#          '구조': 6,
#          '대립': 6,
#          '눈': 6,
#          '부담': 6,
#          '공중': 6,
#          '역대': 6,
#          '스케일': 6,
#          '참고': 6,
#          '성장': 6,
#          '드라마': 6,
#          '이해': 6,
#          '걱정': 6,
#          '시사회': 6,
#          '땅': 6,
#          '연결': 6,
#          '활약': 6,
#          '해당': 6,
#          '이전': 5,
#          '일반': 5,
#          '영상미': 5,
#          '관': 5,
#          '차이': 5,
#          '시각': 5,
#          '흥미': 5,
#          '해결': 5,
#          '세계관': 5,
#          '최고': 5,
#          '흐름': 5,
#          '귀추': 5,
#          '은': 5,
#          '슬픔': 5,
#          '폭력': 5,
#          '소재': 5,
#          '활용': 5,
#          '연기': 5,
#          '포맷': 5,
#          '선사': 5,
#          '메시지': 5,
#          '특징': 5,
#          '토루크': 5,
#          '앞': 5,
#          '단순': 5,
#          '이동': 5,
#          '필수': 5,
#          '출처': 5,
#          '그래픽': 5,
#          '자체': 5,
#          '기술': 5,
#          '결국': 5,
#          '오늘': 5,
#          '쿠키': 5,
#          '포함': 5,
#          '해외': 5,
#          '종족': 5,
#          '일행': 5,
#          '칸': 5,
#          '아래': 5,
#          '압도': 5,
#          '과정': 5,
#          '응모': 5,
#          '출연': 4,
#          '장르': 4,
#          '판타지': 4,
#          '방식': 4,
#          '행동': 4,
#          '딸': 4,
#          '생명체': 4,
#          '파괴': 4,
#          '도움': 4,
#          '인상': 4,
#          '지금': 4,
#          '중심': 4,
#          '기대작': 4,
#          '로': 4,
#          '초반': 4,
#          '월드': 4,
#          '중요': 4,
#          '요소': 4,
#          '안경': 4,
#          '연장선': 4,
#          '필요': 4,
#          '연말': 4,
#          '규모': 4,
#          '숲': 4,
#          '시퀀스': 4,
#          '상황': 4,
#          '탈출': 4,
#          '개인': 4,
#          '요약': 4,
#          '심사': 4,
#          '공개': 4,
#          '잔혹': 4,
#          '반응': 4,
#          '제목': 4,
#          '평점': 4,
#          '목숨': 4,
#          '사실': 4,
#          '사용': 4,
#          '티켓': 4,
#          '값': 4,
#          '부제': 4,
#          '멧케': 4,
#          '신경': 4,
#          '곳': 4,
#          '최후': 4,
#          '작': 4,
#          '멧카': 4,
#          '자원': 4,
#          '사운드': 4,
#          '원주민': 4,
#          '방문': 4,
#          '진행': 4,
#          '형': 3,
#          '예상': 3,
#          '부족장': 3,
#          '반발': 3,
#          '뜻': 3,
#          '편': 3,
#          '정신': 3,
#          '후반': 3,
#          '자랑': 3,
#          '상영관': 3,
#          '티': 3,
#          '손': 3,
#          '적': 3,
#          '감탄': 3,
#          '특별': 3,
#          '스크린': 3,
#          '인정': 3,
#          '포기': 3,
#          '변화': 3,
#          '전체': 3,
#          '일': 3,
#          '피로감': 3,
#          '마지막': 3,
#          '가능': 3,
#          '시네마': 3,
#          '분노': 3,
#          '강조': 3,
#          '발전': 3,
#          '동시': 3,
#          '작용': 3,
#          '바': 3,
#          '입체': 3,
#          '표': 3,
#          '후반부': 3,
#          '비': 3,
#          '비주얼': 3,
#          '소리': 3,
#          '실제': 3,
#          '마찬가지': 3,
#          '망콴': 3,
#          '존재감': 3,
#          '삶': 3,
#          '매력': 3,
#          '하늘': 3,
#          '유사': 3,
#          '납치': 3,
#          '설정': 3,
#          '다양': 3,
#          '돌파': 3,
#          '호불호': 3,
#          '호평': 3,
#          '인터뷰': 3,
#          '평': 3,
#          '명작': 3,
#          '리더': 3,
#          '사악': 3,
#          '하반기': 3,
#          '뒤': 3,
#          '장편': 3,
#          '후속작': 3,
#          '확장': 3,
#          '습격': 3,
#          '로아크': 3,
#          '란': 3,
#          '상태': 3,
#          '나무': 3,
#          '요청': 3,
#          '도중': 3,
#          '산소': 3,
#          '네이티리': 3,
#          '반대': 3,
#          '능력': 3,
#          '연합군': 3,
#          '접근': 3,
#          '동맹': 3,
#          '구출': 3,
#          '얼굴': 3,
#          '온몸': 3,
#          '메인': 3,
#          '소속': 3,
#          '덕분': 3,
#          '확인': 3,
#          '호흡기': 3,
#          '힘': 3,
#          '성격': 3,
#          '상처': 3,
#          '최종': 3,
#          '평화': 3,
#          '망': 3,
#          '폴': 3,
#          '링': 3,
#          '영화제': 3,
#          '고백': 3,
#          '주연': 3,
#          '밤': 3,
#          '여행자': 3,
#          '라이트': 3,
#          '인': 3,
#          '약탈': 3,
#          '호전': 3,
#          '극장가': 3,
#          '나라': 3,
#          '최초': 3,
#          '전국': 3,
#          '초청': 3,
#          '무료': 3,
#          '최장': 3,
#          '국가': 2,
#          '스릴러': 2,
#          '복습': 2,
#          '오프닝': 2,
#          '사망': 2,
#          '자유': 2,
#          '비행': 2,
#          '의식': 2,
#          '엄마': 2,
#          '각종': 2,
#          '의지': 2,
#          '의견': 2,
#          '불안': 2,
#          '문제': 2,
#          '무전기': 2,
#          '기억': 2,
#          '막내': 2,
#          '애': 2,
#          '버벅': 2,
#          '리': 2,
#          '얼마': 2,
#          '목표': 2,
#          '의문': 2,
#          '사고': 2,
#          '회의': 2,
#          '원수': 2,
#          '선': 2,
#          '의미': 2,
#          '악당': 2,
#          '즐거움': 2,
#          '현실': 2,
#          '패턴': 2,
#          '대부분': 2,
#          '오락': 2,
#          '화장실': 2,
#          '기시감': 2,
#          '변수': 2,
#          '표현': 2,
#          '대신': 2,
#          '타이틀': 2,
#          '볼거리': 2,
#          '자기장': 2,
#          '속편': 2,
#          '얘기': 2,
#          '위협': 2,
#          '선택': 2,
#          '증명': 2,
#          '호강': 2,
#          '퀄리티': 2,
#          '숨': 2,
#          '인물': 2,
#          '압박': 2,
#          '주제': 2,
#          '비교': 2,
#          '우호': 2,
#          '대비': 2,
#          '독보': 2,
#          '제공': 2,
#          '퇴장': 2,
#          '전율': 2,
#          '긴장감': 2,
#          '해소': 2,
#          '연인': 2,
#          '주': 2,
#          '아버지': 2,
#          '관계': 2,
#          '최소한': 2,
#          '기회': 2,
#          '경우': 2,
#          '결과': 2,
#          '위원회': 2,
#          '수위': 2,
#          '기존': 2,
#          '실사': 2,
#          '진화': 2,
#          '마무리': 2,
#          '추천작': 2,
#          '출연진': 2,
#          '독특': 2,
#          '외계인': 2,
#          '결심': 2,
#          '발생': 2,
#          '날': 2,
#          '시기': 2,
#          '작가': 2,
#          '기대감': 2,
#          '계속': 2,
#          '구간': 2,
#          '정리': 2,
#          '네테': 2,
#          '영혼': 2,
#          '생활': 2,
#          '화살': 2,
#          '추락': 2,
#          '위': 2,
#          '호흡': 2,
#          '틈': 2,
#          '근거지': 2,
#          '선물': 2,
#          '포위': 2,
#          '합세': 2,
#          '역전': 2,
#          '역할': 2,
#          '사연': 2,
#          '분량': 2,
#          '하이브리드': 2,
#          '배급사': 2,
#          '몰입도': 2,
#          '유대': 2,
#          '덕': 2,
#          '개발': 2,
#          '생존자': 2,
#          '신세': 2,
#          '혈': 2,
#          '학살': 2,
#          '위치': 2,
#          '엔딩': 2,
#          '박스오피스': 2,
#          '포스팅': 2,
#          '살인자': 2,
#          '대전': 2,
#          '직전': 2,
#          '세월': 2,
#          '여성': 2,
#          '경': 2,
#          '데뷔작': 2,
#          '작년': 2,
#          '독립': 2,
#          '자녀': 2,
#          '대표': 2,
#          '평단': 2,
#          '프리즘': 2,
#          '락': 2,
#          '치유': 2,
#          '의': 2,
#          '개봉일': 2,
#          '동네': 2,
#          '특공대': 2,
#          '안녕': 2,
#          '플루': 2,
#          '언': 2,
#          '서': 2,
#          '스타': 2,
#          '티오': 2,
#          '연합': 2,
#          '무리': 2,
#          '어려움': 2,
#          '와이프': 2,
#          '압권': 2,
#          '박진감': 2,
#          '대상': 2,
#          '차별': 2,
#          '부담감': 2,
#          '아역': 2,
#          '모션': 2,
#          '캡처': 2,
#          '의상': 2,
#          '본': 2,
#          '글': 2,
#          '클릭': 2,
#          '내년': 2,
#          '명품': 2,
#          '멤버십': 2,
#          '불편': 2,
#          '통신사': 2,
#          '내한': 2,
#          '기본': 1,
#          '원': 1,
#          '수입': 1,
#          '배급': 1,
#          '컴퍼니': 1,
#          '애도': 1,
#          '포인트': 1,
#          '대화': 1,
#          '상실감': 1,
#          '아무것': 1,
#          '전함': 1,
#          '무기': 1,
#          '분위기': 1,
#          '짜증': 1,
#          '어처구니': 1,
#          '형제': 1,
#          '멧카이': 1,
#          '머리': 1,
#          '의아': 1,
#          '도망': 1,
#          '활': 1,
#          '행적': 1,
#          '달성': 1,
#          '감흥': 1,
#          '전생': 1,
#          '공생': 1,
#          '주먹': 1,
#          '승부': 1,
#          '형사': 1,
#          '도': 1,
#          '범죄자': 1,
#          '소탕': 1,
#          '덧': 1,
#          '심장': 1,
#          '동원': 1,
#          '현재': 1,
#          '추이': 1,
#          '장기': 1,
#          '바탕': 1,
#          '판박이': 1,
#          '변주': 1,
#          '적극': 1,
#          '급부상': 1,
#          '부각': 1,
#          '마녀': 1,
#          '악녀': 1,
#          '주술사': 1,
#          '배': 1,
#          '요염': 1,
#          '팜므': 1,
#          '파탈': 1,
#          '울트라': 1,
#          '평일': 1,
#          '가격': 1,
#          '차': 1,
#          '시': 1,
#          '불빛': 1,
#          '체험': 1,
#          '혁명': 1,
#          '단독': 1,
#          '수용': 1,
#          '경험': 1,
#          '급': 1,
#          '재탕': 1,
#          '키': 1,
#          '워드': 1,
#          '외계': 1,
#          '운명': 1,
#          '을': 1,
#          '상실': 1,
#          '위험': 1,
#          '기로': 1,
#          '당시': 1,
#          '일례': 1,
#          '우스갯소리': 1,
#          '분간': 1,
#          '사실감': 1,
#          '대형': 1,
#          '감사': 1,
#          '현실감': 1,
#          '생동감': 1,
#          '남녀노소': 1,
#          '단위': 1,
#          '영화관': 1,
#          '정석': 1,
#          '체감': 1,
#          '고려': 1,
#          '재난': 1,
#          '재앙': 1,
#          '방관': 1,
#          '풍요': 1,
#          '친화': 1,
#          '결': 1,
#          '이제': 1,
#          '화제': 1,
#          '유의미': 1,
#          '행보': 1,
#          '광기': 1,
#          '내막': 1,
#          '공기': 1,
#          '주머니': 1,
#          '부유': 1,
#          '각지': 1,
#          '물자': 1,
#          '거래': 1,
#          '각각': 1,
#          '사활': 1,
#          '장엄': 1,
#          '가치': 1,
#          '진격': 1,
#          '남발': 1,
#          '반감': 1,
#          '역효과': 1,
#          '동일': 1,
#          '유야무야': 1,
#          '스토리텔링': 1,
#          '외부': 1,
#          '내부': 1,
#          '외부인': 1,
#          '동화': 1,
#          '식구': 1,
#          '포지션': 1,
#          '일원': 1,
#          '생물학': 1,
#          '폭발': 1,
#          '대기': 1,
#          '한몫': 1,
#          '확신': 1,
#          '관점': 1,
#          '영상물': 1,
#          '죽음': 1,
#          '성향': 1,
#          '묘사': 1,
#          '애초': 1,
#          '글로벌': 1,
#          '관건': 1,
#          '환경': 1,
#          '메세지': 1,
#          '경이': 1,
#          '체크': 1,
#          '일부': 1,
#          '디테일': 1,
#          '장점': 1,
#          '무한': 1,
#          '칭찬': 1,
#          '수치': 1,
#          '길이': 1,
#          '손익': 1,
#          '흥행작': 1,
#          '사전': 1,
#          '열광': 1,
#          '새해': 1,
#          '인생': 1,
#          '작성': 1,
#          '사랑': 1,
#          '아내': 1,
#          '자식': 1,
#          '네이티얌이': 1,
#          '네이티얌': 1,
#          '세상': 1,
#          '충격': 1,
#          '절망': 1,
#          '이때': 1,
#          '숙적': 1,
#          '추적자': 1,
#          '동료': 1,
#          '외국': 1,
#          '최신': 1,
#          '조합': 1,
#          '파업': 1,
#          '여파': 1,
#          '충족': 1,
#          '기분': 1,
#          '보통': 1,
#          '단점': 1,
#          '유발': 1,
#          '신파': 1,
#          '몰입': 1,
#          '가미': 1,
#          '요즘': 1,
#          '기피': 1,
#          '현상': 1,
#          '중후반': 1,
#          '카': 1,
#          '망크완': 1,
#          '엔드': 1,
#          '게임': 1,
#          '연도': 1,
#          '시청': 1,
#          '경로': 1,
#          '수준': 1,
#          '르': 1,
#          '매료': 1,
#          '상업': 1,
#          '제왕': 1,
#          '곁': 1,
#          '죄책감': 1,
#          '침략': 1,
#          '금속': 1,
#          '피해': 1,
#          '거절': 1,
#          '수면': 1,
#          '평소': 1,
#          '증오': 1,
#          '오미타카야': 1,
#          '예측': 1,
#          '확보': 1,
#          '뿌리': 1,
#          '발작': 1,
#          '추격': 1,
#          '아까': 1,
#          '천둥': 1,
#          '총알': 1,
#          '투': 1,
#          '인질': 1,
#          '쿼리치': 1,
#          '제압': 1,
#          '포박': 1,
#          '법': 1,
#          '전수': 1,
#          '방심': 1,
#          '식물': 1,
#          '독침': 1,
#          '경비병': 1,
#          '검사': 1,
#          '유전자': 1,
#          '배열': 1,
#          '씨앗': 1,
#          '탄생': 1,
#          '톨쿤': 1,
#          '싸움': 1,
#          '희생': 1,
#          '건의': 1,
#          '추방': 1,
#          '결정': 1,
#          '케이': 1,
#          '포로': 1,
#          '기지': 1,
#          '잠입': 1,
#          '한데': 1,
#          '변호': 1,
#          '협조': 1,
#          '우세': 1,
#          '그때': 1,
#          '시도': 1,
#          '오징어': 1,
#          '지시': 1,
#          '열세': 1,
#          '팔': 1,
#          '전투기': 1,
#          '유린': 1,
#          '전사': 1,
#          '배분': 1,
#          '가장': 1,
#          '구원': 1,
#          '사춘기': 1,
#          '소년': 1,
#          '설득': 1,
#          '실망': 1,
#          '특화': 1,
#          '페인트': 1,
#          '칠': 1,
#          '화산': 1,
#          '지대': 1,
#          '스펙터클': 1,
#          '용암': 1,
#          '속성': 1,
#          '대장': 1,
#          '불길': 1,
#          '옆': 1,
#          '병사': 1,
#          '돌격': 1,
#          '격추': 1,
#          '심도': 1,
#          '면': 1,
#          '평면': 1,
#          '겁': 1,
#          '지적': 1,
#          '빈약': 1,
#          '승리': 1,
#          '양': 1,
#          '피로': 1,
#          '식상': 1,
#          '머릿속': 1,
#          '이견': 1,
#          '할애': 1,
#          '이외': 1,
#          '파트': 1,
#          '해상': 1,
#          '상상력': 1,
#          '창의력': 1,
#          '범죄': 1,
#          '도시': 1,
#          '고착': 1,
#          '사진': 1,
#          '대세': 1,
#          '동식물': 1,
#          '황홀경': 1,
#          '단락': 1,
#          '동어': 1,
#          '퇴근': 1,
#          '피곤': 1,
#          '중간': 1,
#          '런닝': 1,
#          '희망': 1,
#          '쟁탈전': 1,
#          '여전사': 1,
#          '진면목': 1,
#          '악역': 1,
#          '전락': 1,
#          '졸지': 1,
#          '세간': 1,
#          '흡입력': 1,
#          '보장': 1,
#          '외전': 1,
#          '수중': 1,
#          '부재': 1,
#          '플롯': 1,
#          '완벽': 1,
#          '완결': 1,
#          '기약': 1,
#          '완성': 1,
#          '샘': 1,
#          '철천지': 1,
#          '코': 1,
#          '장군': 1,
#          '지원': 1,
#          '병력': 1,
#          '묵살': 1,
#          '연구원': 1,
#          '제안': 1,
#          '생존': 1,
#          '불시착': 1,
#          '여분': 1,
#          '과': 1,
#          '여정': 1,
#          '협력': 1,
#          '박사': 1,
#          '챔피언': 1,
#          '총괄': 1,
#          '셀프': 1,
#          '정착': 1,
#          '생포': 1,
#          '명령': 1,
#          '환심': 1,
#          '친구': 1,
#          '툴': 1,
#          '단신': 1,
#          '남편': 1,
#          '조': 1,
#          '포획': 1,
#          '친': 1,
#          '부': 1,
#          '아저씨': 1,
#          '날짜': 1,
#          '의회': 1,
#          '장로': 1,
#          '온건': 1,
#          '씨알': 1,
#          '레오놉테릭스를': 1,
#          '분해': 1,
#          '여신': 1,
#          '기도': 1,
#          '전세': 1,
#          '총공격': 1,
#          '가운데': 1,
#          '함선': 1,
#          '박살': 1,
#          '낑겨': 1,
#          '밑': 1,
#          '아군': 1,
#          '생사': 1,
#          '특유': 1,
#          '프릴': 1,
#          '크레딧': 1,
#          '상당': 1,
#          '만남': 1,
#          '데이터': 1,
#          '진흥': 1,
#          '통합': 1,
#          '전산망': 1,
#          '기준': 1,
#          '추정': 1,
#          '제작비': 1,
#          '투입': 1,
#          '블록버스터': 1,
#          '달': 1,
#          '평론가': 1,
#          '측면': 1,
#          '양질': 1,
#          '만회': 1,
#          '치외': 1,
#          '법권': 1,
#          '동명': 1,
#          '소설': 1,
#          '원작': 1,
#          '투병': 1,
#          '강서': 1,
#          '하': 1,
#          '유작': 1,
#          '위원': 1,
#          '상': 1,
#          '수상': 1,
#          '직후': 1,
#          '세기': 1,
#          '알': 1,
#          '지역': 1,
#          '농장': 1,
#          '캐스팅': 1,
#          '공': 1,
#          '완성도': 1,
#          '린': 1,
#          '스키': 1,
#          '정식': 1,
#          '호응': 1,
#          '현': 1,
#          '이혼녀': 1,
#          '질풍노도': 1,
#          '소녀': 1,
#          '실존': 1,
#          '심야': 1,
#          '라디오': 1,
#          '쇼': 1,
#          '영감': 1,
#          '프랑스인': 1,
#          '향수': 1,
#          '자극': 1,
#          '추억': 1,
#          '여행': 1,
#          '대중': 1,
#          '양쪽': 1,
#          '극찬': 1,
#          '부부': 1,
#          '미': 1,
#          '비평가': 1,
#          '협회': 1,
#          '반': 1,
#          '민영': 1,
#          '감정': 1,
#          '내면': 1,
#          '현대인': 1,
#          '아픔': 1,
#          '보편': 1,
#          '공감대': 1,
#          '의도': 1,
#          '곽': 1,
#          '민': 1,
#          '영': 1,
#          '하루': 1,
#          '경고': 1,
#          '준비': 1,
#          '운': 1,
#          '당첨': 1,
#          '연맹': 1,
#          '바닷속': 1,
#          '독자': 1,
#          '문화': 1,
#          '형성': 1,
#          '우퍼': 1,
#          '발췌': 1,
#          '지구': 1,
#          '천연': 1,
#          '고갈': 1,
#          '에너지난': 1,
#          '관리국': 1,
#          '기업': 1,
#          '식민지': 1,
#          '공존': 1,
#          '균형': 1,
#          '중시': 1,
#          '지도자': 1,
#          '장남': 1,
#          '트라우마': 1,
#          '고군분투': 1,
#          '로아크와': 1,
#          '담당': 1,
#          '과학자': 1,
#          '악연': 1,
#          '본질': 1,
#          '스파이크': 1,
#          '피아': 1,
#          '식별': 1,
#          '정체': 1,
#          '육체': 1,
#          '피지컬': 1,
#          '보유': 1,
#          '카리스마': 1,
#          '동족': 1,
#          '개념': 1,
#          ...})

# %%
# 상위 100개 단어만 추출
top_100 = counter.most_common(100)

# %%
wc = WordCloud(
    font_path='C:/Windows/Fonts/malgunbd.ttf',
    background_color='white'    
).generate_from_frequencies(dict(top_100))
plt.imshow(wc)
plt.axis('off')
plt.show()
