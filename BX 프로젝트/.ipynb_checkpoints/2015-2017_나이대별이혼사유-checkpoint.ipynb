# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic') #한글 깨짐 방지

# %%
df = pd.read_csv('./2015-2017이혼사유.csv', encoding='utf-8', index_col='연도') #데이터 불러오기

# %%
df.loc[:, '계':] = df.loc[:, '계':].replace({',': ''}, regex=True).apply(pd.to_numeric) #숫자형 변환
ratio_cols = df.columns[df.columns.get_loc('계') + 1:] # 각 열을 퍼센테이지 변환을 위한 컬럼 목록 지정
df[ratio_cols] = df[ratio_cols].div(df['계'], axis=0) * 100 # 이혼 사유 전체를 퍼센트 변환
df
# Out:
#            연령별      계    배우자 부정 정신적,육체적 학대    가족간 불화      경제문제       성격차이  \
# 연도
# 2015  20 - 24세   1067  5.342081   4.029991  9.559513  6.466729   51.35895
# 2015  25 - 29세   3295  7.951442   3.854325  9.013657  6.009105  50.834598
# 2015  30 - 34세   9904  8.340065   3.261309   7.53231  6.542811  51.989095
# 2016  20 - 24세   2993  7.317073   3.575008  7.985299  4.677581  44.737721
# 2016  25 - 29세   7225  8.512111   3.391003  8.055363  5.190311  48.276817
# 2016  30 - 34세  13575  7.771639   3.388582  7.683241  6.983425  49.782689
# 2017  20 - 24세   2782  8.159597   3.666427  9.489576  4.565061  42.487419
# 2017  25 - 29세   7126    8.6865   3.438114  8.083076  5.739545  46.154926
# 2017  30 - 34세  12857  7.762308   3.756708  7.567862  6.914521  47.584973
#
#           건강문제         기타        미상
# 연도
# 2015  0.374883  20.431115  2.436739
# 2015   0.30349  19.787557  2.245827
# 2015  0.292811  20.072698  1.968901
# 2016  0.400936  27.163381     4.143
# 2016  0.373702  21.702422   4.49827
# 2016   0.39779  19.005525  4.987109
# 2017  0.287563  25.880661  5.463695
# 2017  0.336795  21.077743  6.483301
# 2017  0.318892  19.149102  6.945633

# %%
df_2015 = df.loc[2015].set_index('연령별') # 2015에 해댕하는 모든 행

df_2015.loc[:, '배우자 부정':].plot(kind='barh') # 기존 인덱스를 연령별로 변경 -> y축으로 사용
plt.xlabel('비율(%)')
plt.ylabel('연령별')
plt.title('2015년 연령별 이혼사유 비율')
plt.legend(bbox_to_anchor=(1.5, 0.5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 9
#       7 # 히트맵
#       8 plt.figure(figsize=(12, 6))
# ----> 9 plt.imshow(data, aspect='auto')
#      10 plt.colorbar(label='비율(%)')
#      12 plt.xticks(range(len(data.columns)), data.columns, rotation=45, ha='right')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3601, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3579 @_copy_docstring_and_deprecators(Axes.imshow)
#    3580 def imshow(
#    3581     X: ArrayLike | PIL.Image.Image,
#    (...)   3599     **kwargs,
#    3600 ) -> AxesImage:
# -> 3601     __ret = gca().imshow(
#    3602         X,
#    3603         cmap=cmap,
#    3604         norm=norm,
#    3605         aspect=aspect,
#    3606         interpolation=interpolation,
#    3607         alpha=alpha,
#    3608         vmin=vmin,
#    3609         vmax=vmax,
#    3610         colorizer=colorizer,
#    3611         origin=origin,
#    3612         extent=extent,
#    3613         interpolation_stage=interpolation_stage,
#    3614         filternorm=filternorm,
#    3615         filterrad=filterrad,
#    3616         resample=resample,
#    3617         url=url,
#    3618         **({"data": data} if data is not None else {}),
#    3619         **kwargs,
#    3620     )
#    3621     sci(__ret)
#    3622     return __ret
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:5982, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5979 if aspect is not None:
#    5980     self.set_aspect(aspect)
# -> 5982 im.set_data(X)
#    5983 im.set_alpha(alpha)
#    5984 if im.get_clip_path() is None:
#    5985     # image does not already have clipping set, clip to Axes patch
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:685, in _ImageBase.set_data(self, A)
#     683 if isinstance(A, PIL.Image.Image):
#     684     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 685 self._A = self._normalize_image_array(A)
#     686 self._imcache = None
#     687 self.stale = True
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:648, in _ImageBase._normalize_image_array(A)
#     646 A = cbook.safe_masked_invalid(A, copy=True)
#     647 if A.dtype != np.uint8 and not np.can_cast(A.dtype, float, "same_kind"):
# --> 648     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     649                     f"converted to float")
#     650 if A.ndim == 3 and A.shape[-1] == 1:
#     651     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
df_2016 = df.loc[2016].set_index('연령별')

df_2016.loc[:, '배우자 부정':].plot(kind='barh')
plt.xlabel('비율(%)')
plt.ylabel('연령별')
plt.title('2016년 연령별 이혼사유 비율')
plt.legend(bbox_to_anchor=(1.5, 0.5))
plt.show()

# %%
df_2017 = df.loc[2017].set_index('연령별')

df_2017.loc[:, '배우자 부정':].plot(kind='barh')
plt.xlabel('비율(%)')
plt.ylabel('연령별')
plt.title('2017년 연령별 이혼사유 비율')
plt.legend(bbox_to_anchor=(1.5, 0.5))
plt.show()
