# %%
# 라이브러리 불러오기
import selenium.webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from tqdm import tqdm
import pandas as pd
import re # 정규표현식
from kiwipiepy import Kiwi # 키위 형태소 분석기
from wordcloud import WordCloud # 워드클라우드 생성 도구
from collections import Counter # 단어가 나온 횟수를 세주는 도구
import matplotlib.pyplot as plt #t시각화도구
from nltk.util import ngrams

# 문자열 전처리 함수 -> 숫자, 문자, (?.!,¿) 제외하고 공백으로 대체
def preprocess_sentence_kr(w):
  w = w.strip()
  w = re.sub(r"[^0-9가-힣?.!,¿]+", " ", w) 
  w = w.strip() 
  return w

def make_bi_token(tokens):
    bi_tokens = list(ngrams(tokens,2))
    return tokens + [' '.join(bi) for bi in bi_tokens]

# %%
driver = wb.Chrome()
driver.get('https://www.naver.com/')
# 검생창의 위치를 드라이버에게 공유
driver.find_element(By.ID,'query').send_keys('신혼 갈등'+'\n')

# %%
tab = driver.find_elements(By.CSS_SELECTOR,'a.tab') 
tab[3].click()

# %%
for i in range(10):
    body = driver.find_element(By.TAG_NAME,'body')
    body.send_keys(Keys.END)
    time.sleep(1)

# %%
href_list=[]
link = driver.find_elements(By.CSS_SELECTOR,'a.fender-ui_228e3bd1.ufSCQP1M3E9SJkaKbZ69')
for i in range(len(link)):
    href_list.append(link[i].get_attribute('href'))

# %%
href_list
# Out:
# ['https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60215&docId=490926103&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80102&docId=490436234&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=184632697&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=10&dirId=100602&docId=184600732&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=408&docId=292441571&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=801&docId=422426781&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40201&docId=382304973&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=138139883&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80102&docId=484297866&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=7&dirId=70117&docId=460996444&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=410206817&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=447872140&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=20&dirId=200107&docId=179997213&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=249581926&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=61303&docId=275450197&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60215&docId=491477666&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=354869981&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60215&docId=491715462&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=363417439&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=448741812&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=489886849&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1130&docId=485128306&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110302&docId=389602083&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60215&docId=466509634&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=439665708&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1130&docId=485128305&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=467274031&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=170252051&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=30301&docId=489583128&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60215&docId=488461230&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=410018446&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60211&docId=299047690&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60221&docId=460849246&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=478514621&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=483733796&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=4020201&docId=491553632&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=6020604&docId=470737476&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=491764989&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=4010501&docId=363559518&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31501&docId=436255916&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40203&docId=456521882&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60215&docId=489137008&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=285046457&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1111&docId=338734116&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80102&docId=489898224&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=490851733&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8&docId=30070266&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80801&docId=257780595&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31506&docId=488162429&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=285091738&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=3010101&docId=489882215&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=455167715&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=3010101&docId=490088361&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=508&docId=488602763&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=408&docId=424650255&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=3010101&docId=489964601&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60215&docId=467672813&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=29506709&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=51002&docId=478228078&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=3010101&docId=489881592&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40101&docId=486443013&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=902&docId=74470541&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80102&docId=482001963&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=809&docId=482706267&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60501&docId=450319701&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=4010502&docId=478454907&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=9020201&docId=484986234&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40201&docId=464111478&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=423370239&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=483816540&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60215&docId=489939399&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1111&docId=332864471&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1111&docId=431956914&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80107&docId=468551957&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=454980976&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=486506146&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=457322955&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1130&docId=467493721&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1130&docId=380148069&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=61303&docId=240199997&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80102&docId=488878790&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=4010502&docId=464209167&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60220&docId=487950332&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=487742219&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=4020201&docId=356639718&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=470202984&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60202&docId=486134134&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1130&docId=486730555&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=4010501&docId=468472019&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40201&docId=382207679&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=449309595&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80102&docId=478703228&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=487967770&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=490738965&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=4020201&docId=447002629&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=4010506&docId=154581504&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=4020201&docId=462560187&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=281202289&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60215&docId=485253395&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=31158997&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=468527186&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=3010101&docId=489880407&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=488055856&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=438371145&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40204&docId=464135541&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80102&docId=491026471&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=4010502&docId=485041309&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40202&docId=456508404&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=4020201&docId=425146827&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60204&docId=488830728&enc=utf8&kinsrch_src=pc_tab_kin&qb=7Iug7Zi8IOqwiOuTsQ%3D%3D']

# %%
len(href_list)
# Out:
# 110

# %%
driver.get(href_list[0])
time.sleep(2)
result=driver.find_elements(By.CSS_SELECTOR,'div.questionDetail')
result[0].text
# Out:
# '결혼한지 5개월차, 동거 1년차 신혼입니다.\n항상 싸움이 있을 때마다 니가 문제다 니가 이렇게 했기 때문에 내가 이러는거다 라는 식의 싸움을 반복했고 어느 순간부터는 니가 이러니까 욕을 처먹는거다 라는 말로 온갖 폭언을 들었습니다.\n그러는 과정에 서로 몸싸움도 하면서 상황은 더 안좋아지는것 같아요\n똑같이 싸우면 안되는데 똑같이 한 부분에 있어서는 당연히 잘한거 없다고 생각하지만 늘 폭언과 니가 해온게뭐냐(결혼할때 시댁에서 전세자금으로 돈 일부 해주심, 결혼에 필요한 비용+전세자금일부는 제가함) 로 매번 싸울때마다 집에서 나가라 니가(니네 집에서) 해준게뭐냐의 반복입니다. 그리고 애시당초 저희는 경제공동체도 아닌듯한 발언들에 지치네요\n솔직히 말하면 당장 이혼이 맞는지도 모르겠고 그렇다고 왜 이렇게 살아아하는지도 잘 모르겠고 정확한 현재 상태에 대한 진단, 앞으로 준비해야하는부분(이혼을 안하더라도 뭔가 증거수집이라던지? 이혼을 한다면 어쩐부분을 준비해야하는지) 전문적인 상담을 통해 객관적인 시선으로 앞으로를 고민해보고싶습니다.\n\n관련태그: 이혼, 가사 일반'

# %%
f = open('./data/신혼 갈등 네이버지식인 질문.txt','w')

# 링크 반복
for i in tqdm(range(len(href_list))):
    driver.get(href_list[i])
    time.sleep(2)


    result=driver.find_elements(By.CSS_SELECTOR,'div.questionDetail')
    for j in range(len(result)):
        content = preprocess_sentence_kr(result[j].text)
        f.write(content)

f.close()   
driver.quit()
# Out:
# 100%|██████████| 110/110 [04:46<00:00,  2.60s/it]

# %%
# 텍스트 파일 열기
f = open('./data/신혼 갈등 네이버지식인 질문.txt','r')
text = f.readline()
f.close()

# %%
# 도구 객체생성
kiwi = Kiwi()
# 토큰화
token = kiwi.tokenize(text)

nn_list=[]
for t in token:
    if t.tag in ['NNG','NNP']:
        nn_list.append(t.form)

# %%
nn_list=make_bi_token(nn_list)

# %%
top_100 = Counter(nn_list).most_common(100)
top_100
# Out:
# [('결혼', 183),
#  ('집', 183),
#  ('남편', 129),
#  ('말', 115),
#  ('이혼', 115),
#  ('아내', 103),
#  ('때', 102),
#  ('생각', 96),
#  ('신혼', 90),
#  ('대출', 84),
#  ('부모', 79),
#  ('갈등', 76),
#  ('부부', 75),
#  ('아이', 67),
#  ('일', 63),
#  ('사람', 60),
#  ('문제', 58),
#  ('돈', 54),
#  ('엄마', 53),
#  ('정도', 52),
#  ('남자', 49),
#  ('전화', 49),
#  ('상황', 48),
#  ('전', 47),
#  ('시댁', 46),
#  ('상담', 46),
#  ('신혼부부', 46),
#  ('전세', 45),
#  ('얘기', 43),
#  ('장모', 43),
#  ('어머니', 43),
#  ('마음', 40),
#  ('친구', 38),
#  ('신랑', 37),
#  ('후', 35),
#  ('아파트', 34),
#  ('와이프', 33),
#  ('여자', 32),
#  ('본인', 32),
#  ('생활', 31),
#  ('친정', 30),
#  ('명의', 29),
#  ('상태', 28),
#  ('아들', 27),
#  ('시어머니', 27),
#  ('애기', 25),
#  ('시작', 24),
#  ('안녕', 24),
#  ('준비', 23),
#  ('사이', 23),
#  ('말씀', 23),
#  ('시간', 23),
#  ('걱정', 23),
#  ('연락', 23),
#  ('직장', 23),
#  ('연애', 22),
#  ('가능', 22),
#  ('소리', 21),
#  ('가족', 21),
#  ('욕', 20),
#  ('부분', 20),
#  ('내용', 20),
#  ('이상', 20),
#  ('기분', 19),
#  ('이야기', 19),
#  ('그때', 19),
#  ('혼수', 19),
#  ('결혼 전', 19),
#  ('신혼 부부', 19),
#  ('싸움', 18),
#  ('이해', 18),
#  ('대화', 18),
#  ('날', 18),
#  ('이후', 18),
#  ('출산', 18),
#  ('앞', 17),
#  ('결혼식', 17),
#  ('부탁', 17),
#  ('라', 17),
#  ('행동', 17),
#  ('딸', 17),
#  ('처음', 17),
#  ('임신', 17),
#  ('신고', 16),
#  ('대답', 16),
#  ('관계', 16),
#  ('집안', 16),
#  ('혼자', 16),
#  ('혼인', 15),
#  ('애', 15),
#  ('아빠', 15),
#  ('방', 15),
#  ('술', 15),
#  ('선물', 15),
#  ('신혼 집', 15),
#  ('고민', 14),
#  ('해결', 14),
#  ('사랑', 14),
#  ('지역', 14),
#  ('아기', 14)]

# %%
wc = WordCloud(
    font_path='C:/Windows/Fonts/malgunbd.ttf',
    background_color='white'    
).generate_from_frequencies(dict(top_100))
plt.imshow(wc)
plt.axis('off')
plt.show()
